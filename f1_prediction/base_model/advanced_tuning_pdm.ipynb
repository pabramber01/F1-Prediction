# %% [markdown]
# # Is podium

# %% [markdown]
# ## Dependencies

# %% [markdown]
# The dependencies used are as follows

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import make_scorer

import sys

sys.path.append("..")

from utils.visualization import model_tuning
from utils.custom_cvs import VariableTimeSeriesSplit
from utils.custom_scorers import balanced_accuracy_score

import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import warnings

warnings.simplefilter("ignore")

# %% [markdown]
# ## Initialization

# %% [markdown]
# We continue with the tuning of the model that predicts the podium

# %%
df = pd.read_csv("../assets/data/processed/base_model.csv")

mid_rc = df.groupby("raceYear")["raceRound"].max().to_numpy() // 2
get_half = lambda x: f'{x["raceYear"]}{x["raceRound"] <= mid_rc[x["raceYear"] - 2006]}'
instances_per_half = df.apply(get_half, axis=1).value_counts(sort=False).to_numpy()

n_splits = len(instances_per_half) - 10
max_train_size = [instances_per_half[i : 10 + i].sum() for i in range(n_splits)]
test_size = instances_per_half[10:].tolist()
tscv = VariableTimeSeriesSplit(
    n_splits=n_splits, max_train_size=max_train_size, test_size=test_size
)

podiums = df[df["positionFinal"].isin([1, 2, 3])][
    ["raceYear", "raceRound", "driverRef"]
]
podiums = podiums.groupby(by=["raceYear", "raceRound"]).agg({"driverRef": ",".join})

X = pd.read_csv("../assets/data/processed/base_model_X.csv")
y = df.merge(podiums, how="left", on=["raceYear", "raceRound"], suffixes=("", "Podium"))
y = y.apply(lambda x: x["driverRef"] in x["driverRefPodium"], axis=1)

# %% [markdown]
# ## K-Nearest Neighbors

# %%
X_selected = X[
    [
        "carNumber",
        "positionGrid",
        "driverRef",
        "driverNationality",
        "constructorRef",
        "raceYear",
        "driverWins",
        "constructorWins",
    ]
]
params = [
    ("int", ("n_neighbors", 1, 101)),
    ("categorical", ("metric", ["cosine", "euclidean", "manhattan"])),
    ("categorical", ("weights", ["distance", "uniform"])),
]
model = KNeighborsClassifier
scoring = make_scorer(balanced_accuracy_score)
model_tuning(params, model, X_selected, y, tscv, scoring)
# Out:
# KNeighborsClassifier: 0.778 with {'n_neighbors': 24, 'metric': 'cosine', 'weights':
# 	'distance'}

# %% [markdown]
# ## Decision Tree

# %%
X_selected = X[
    [
        "positionGrid",
        "driverNationality",
        "constructorRef",
        "constructorNationality",
        "raceYear",
        "raceRound",
        "grandPrix",
        "circuitRef",
        "circuitLocation",
        "circuitCountry",
        "circuitLng",
        "driverWins",
        "constructorWins",
        "q3",
    ]
]
params = [
    ("int", ("max_depth", 1, 15)),
    ("categorical", ("criterion", ["gini", "log_loss", "entropy"])),
    ("categorical", ("splitter", ["best", "random"])),
]
model = DecisionTreeClassifier
scoring = make_scorer(balanced_accuracy_score)
model_tuning(params, model, X_selected, y, tscv, scoring)
# Out:
# DecisionTreeClassifier: 0.800 with {'max_depth': 4, 'criterion': 'log_loss', 'splitter':
# 	'best'}

# %% [markdown]
# ## Random Forest

# %%
X_selected = X[
    [
        "positionGrid",
        "driverNumber",
        "driverNationality",
        "constructorRef",
        "raceYear",
        "driverWins",
        "constructorWins",
        "q1",
        "driverAgeAtRace",
    ]
]
params = [
    ("int", ("max_depth", 1, 50)),
    ("int", ("n_estimators", 1, 500)),
    ("categorical", ("criterion", ["gini", "log_loss", "entropy"])),
]
model = RandomForestClassifier
scoring = make_scorer(balanced_accuracy_score)
model_tuning(params, model, X_selected, y, tscv, scoring)
# Out:
# RandomForestClassifier: 0.790 with {'max_depth': 9, 'n_estimators': 387, 'criterion':
# 	'log_loss'}

# %% [markdown]
# ## Multilayer Perceptron

# %%
X_selected = X[
    [
        "positionGrid",
        "raceYear",
        "grandPrix",
        "circuitLocation",
        "circuitCountry",
        "circuitLat",
        "circuitAlt",
        "driverWins",
        "constructorWins",
        "q1",
        "q2",
    ]
]
params = [
    ("categorical", ("activation", ["tanh", "logistic", "relu", "identity"])),
    ("mlp", ("hidden_layer_sizes", 10, 100)),
]
model = MLPClassifier
scoring = make_scorer(balanced_accuracy_score)
model_tuning(params, model, X_selected, y, tscv, scoring)
# Out:
# MLPClassifier: 0.804 with {'activation': 'logistic', 'n_layers': 5, 'n_units_0': 71,
# 	'n_units_1': 19, 'n_units_2': 76, 'n_units_3': 43, 'n_units_4': 40}

# %% [markdown]
# ## Results

# %% [markdown]
# Therefore, the tuning for each algorithm are as follows
#
# - KNeighborsClassifier: 0.778 with {'n_neighbors': 24, 'metric': 'cosine', 'weights': 'distance'}
# - DecisionTreeClassifier: 0.800 with {'max_depth': 4, 'criterion': 'log_loss', 'splitter': 'best'}
# - RandomForestClassifier: 0.790 with {'max_depth': 9, 'n_estimators': 387, 'criterion': 'log_loss'}
# - MLPClassifier: 0.804 with {'activation': 'logistic', 'n_layers': 5, 'n_units_0': 71, 'n_units_1': 19, 'n_units_2': 76, 'n_units_3': 43, 'n_units_4': 40}
