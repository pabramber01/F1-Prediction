# %% [markdown]
# # Is podium

# %% [markdown]
# ## Dependencies

# %% [markdown]
# The dependencies used are as follows

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import make_scorer

import sys

sys.path.append("..")

from utils.visualization import model_tuning
from utils.custom_cvs import VariableTimeSeriesSplit
from utils.custom_scorers import balanced_accuracy_score

import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import warnings

warnings.simplefilter("ignore")

# %% [markdown]
# ## Initialization

# %% [markdown]
# We continue with the tuning of the model that predicts the podium

# %%
df = pd.read_csv("../assets/data/processed/outliers.csv")

mid_rc = df.groupby("raceYear")["raceRound"].max().to_numpy() // 2
get_half = lambda x: f'{x["raceYear"]}{x["raceRound"] <= mid_rc[x["raceYear"] - 2006]}'
instances_per_half = df.apply(get_half, axis=1).value_counts(sort=False).to_numpy()

n_splits = len(instances_per_half) - 10
max_train_size = [instances_per_half[i : 10 + i].sum() for i in range(n_splits)]
test_size = instances_per_half[10:].tolist()
tscv = VariableTimeSeriesSplit(
    n_splits=n_splits, max_train_size=max_train_size, test_size=test_size
)

podiums = df[df["positionFinal"].isin([1, 2, 3])][
    ["raceYear", "raceRound", "driverRef"]
]
podiums = podiums.groupby(by=["raceYear", "raceRound"]).agg({"driverRef": ",".join})

X = pd.read_csv("../assets/data/processed/outliers_X.csv")
y = df.merge(podiums, how="left", on=["raceYear", "raceRound"], suffixes=("", "Podium"))
y = y.apply(lambda x: x["driverRef"] in x["driverRefPodium"], axis=1)

# %% [markdown]
# ## K-Nearest Neighbors

# %%
X_selected = X[
    [
        "carNumber",
        "positionGrid",
        "driverRef",
        "driverNumber",
        "constructorWins",
        "driverAgeToday",
    ]
]
params = [
    ("int", ("n_neighbors", 1, 101)),
    ("categorical", ("metric", ["cosine", "euclidean", "manhattan"])),
    ("categorical", ("weights", ["distance", "uniform"])),
]
model = KNeighborsClassifier
scoring = make_scorer(balanced_accuracy_score)
model_tuning(params, model, X_selected, y, tscv, scoring)
# Out:
# KNeighborsClassifier: 0.804 with {'n_neighbors': 97, 'metric': 'cosine', 'weights':
# 	'distance'}

# %% [markdown]
# ## Decision Tree

# %%
X_selected = X[
    [
        "positionGrid",
        "driverNumber",
        "raceRound",
        "circuitLat",
        "circuitLng",
        "driverWins",
    ]
]
params = [
    ("int", ("max_depth", 1, 15)),
    ("categorical", ("criterion", ["gini", "log_loss", "entropy"])),
    ("categorical", ("splitter", ["best", "random"])),
]
model = DecisionTreeClassifier
scoring = make_scorer(balanced_accuracy_score)
model_tuning(params, model, X_selected, y, tscv, scoring)
# Out:
# DecisionTreeClassifier: 0.852 with {'max_depth': 1, 'criterion': 'log_loss', 'splitter':
# 	'best'}

# %% [markdown]
# ## Random Forest

# %%
X_selected = X[
    [
        "positionGrid",
        "driverWins",
    ]
]
params = [
    ("int", ("max_depth", 1, 50)),
    ("int", ("n_estimators", 1, 500)),
    ("categorical", ("criterion", ["gini", "log_loss", "entropy"])),
]
model = RandomForestClassifier
scoring = make_scorer(balanced_accuracy_score)
model_tuning(params, model, X_selected, y, tscv, scoring)
# Out:
# RandomForestClassifier: 0.811 with {'max_depth': 4, 'n_estimators': 371, 'criterion':
# 	'gini'}

# %% [markdown]
# ## Multilayer Perceptron

# %%
X_selected = X[
    [
        "positionGrid",
        "driverRef",
        "constructorRef",
        "raceYear",
        "raceRound",
        "grandPrix",
        "circuitRef",
        "circuitLocation",
        "circuitCountry",
        "circuitAlt",
        "driverWins",
        "constructorWins",
        "q1",
        "q2",
        "driverAgeToday",
    ]
]
params = [
    ("categorical", ("activation", ["tanh", "logistic", "relu", "identity"])),
    ("mlp", ("hidden_layer_sizes", 10, 100)),
]
model = MLPClassifier
scoring = make_scorer(balanced_accuracy_score)
model_tuning(params, model, X_selected, y, tscv, scoring)
# Out:
# MLPClassifier: 0.839 with {'activation': 'logistic', 'n_layers': 4, 'n_units_0': 23,
# 	'n_units_1': 4, 'n_units_2': 15, 'n_units_3': 15}

# %% [markdown]
# ## Results

# %% [markdown]
# Therefore, the tuning for each algorithm are as follows
#
# - KNeighborsClassifier: 0.804 with {'n_neighbors': 97, 'metric': 'cosine', 'weights': 'distance'}
# - DecisionTreeClassifier: 0.852 with {'max_depth': 1, 'criterion': 'log_loss', 'splitter': 'best'}
# - RandomForestClassifier: 0.811 with {'max_depth': 4, 'n_estimators': 371, 'criterion': 'gini'}
# - MLPClassifier: 0.839 with {'activation': 'logistic', 'n_layers': 4, 'n_units_0': 23, 'n_units_1': 4, 'n_units_2': 15, 'n_units_3': 15}
