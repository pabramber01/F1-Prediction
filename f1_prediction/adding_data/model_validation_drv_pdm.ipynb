# %% [markdown]
# # Is podium

# %% [markdown]
# ## Dependencies

# %% [markdown]
# The dependencies used are as follows

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import make_scorer

import sys

sys.path.append("..")

from utils.visualization import model_test
from utils.custom_cvs import VariableTimeSeriesSplit
from utils.custom_scorers import balanced_accuracy_score

import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import warnings

warnings.simplefilter("ignore")

# %% [markdown]
# ## Initialization

# %% [markdown]
# We continue with the validation of the model that predicts the podium

# %%
df = pd.read_csv("../assets/data/processed/driver_ratings.csv")

instances_per_year = df["raceYear"].value_counts(sort=False)
instances_per_half = (
    np.array(
        list(zip(np.floor(instances_per_year / 2), np.ceil(instances_per_year / 2)))
    )
    .flatten()
    .astype(np.int32)
)

n_splits = len(instances_per_half) - 10
max_train_size = [instances_per_half[i : 10 + i].sum() for i in range(n_splits)]
test_size = instances_per_half[10:].tolist()
tscv = VariableTimeSeriesSplit(
    n_splits=n_splits, max_train_size=max_train_size, test_size=test_size
)

scorers = [make_scorer(balanced_accuracy_score)]
labels = np.array(["not_podium", "podium"])
podiums = df[df["positionFinal"].isin([1, 2, 3])][
    ["raceYear", "raceRound", "driverRef"]
]
podiums = podiums.groupby(by=["raceYear", "raceRound"]).agg({"driverRef": ",".join})

X = pd.read_csv("../assets/data/processed/driver_ratings_X.csv")
y = df.merge(podiums, how="left", on=["raceYear", "raceRound"], suffixes=("", "Podium"))
y = y.apply(lambda x: x["driverRef"] in x["driverRefPodium"], axis=1)

# %% [markdown]
# ## K-Nearest Neighbors

# %%
X_selected = X[
    [
        "carNumber",
        "positionGrid",
        "driverNumber",
        "constructorRef",
        "raceYear",
        "driverWins",
        "driverExp",
        "driverRac",
        "driverAwa",
        "driverPac",
        "driverOvr",
    ]
]
knn = KNeighborsClassifier(n_neighbors=53, metric="cosine", weights="distance")
model_test((knn,), X_selected, y, tscv, scorers=scorers, labels=labels)
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=53, weights='distance'):
# CV with make_scorer(balanced_accuracy_score): 0.7420580751894941
#               precision    recall  f1-score   support
#
#   not_podium       0.93      0.94      0.93      4545
#       podium       0.61      0.54      0.58       756
#
#     accuracy                           0.89      5301
#    macro avg       0.77      0.74      0.76      5301
# weighted avg       0.88      0.89      0.88      5301

# %%
knn = KNeighborsClassifier(n_neighbors=53, metric="cosine", weights="distance")
model_test((knn,), X, y, tscv, scorers=scorers, labels=labels)
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=53, weights='distance'):
# CV with make_scorer(balanced_accuracy_score): 0.7169607975351171
#               precision    recall  f1-score   support
#
#   not_podium       0.92      0.95      0.94      4545
#       podium       0.64      0.49      0.55       756
#
#     accuracy                           0.89      5301
#    macro avg       0.78      0.72      0.74      5301
# weighted avg       0.88      0.89      0.88      5301

# %% [markdown]
# ## Decision Tree

# %%
X_selected = X[
    [
        "carNumber",
        "positionGrid",
        "driverRef",
        "constructorRef",
        "constructorNationality",
        "raceYear",
        "raceRound",
        "grandPrix",
        "raceTime",
        "circuitRef",
        "circuitLocation",
        "circuitCountry",
        "circuitLat",
        "circuitLng",
        "circuitAlt",
        "driverWins",
        "constructorWins",
        "q1",
        "q2",
        "q3",
        "driverExp",
        "driverRac",
        "driverAwa",
        "driverPac",
        "driverOvr",
    ]
]
tree = DecisionTreeClassifier(max_depth=3, criterion="gini", splitter="best")
model_test((tree,), X_selected, y, tscv, scorers=scorers, labels=labels)
# Out:
# DecisionTreeClassifier(max_depth=3):
# CV with make_scorer(balanced_accuracy_score): 0.7917494582165608
#               precision    recall  f1-score   support
#
#   not_podium       0.94      0.95      0.94      4545
#       podium       0.67      0.63      0.65       756
#
#     accuracy                           0.90      5301
#    macro avg       0.80      0.79      0.80      5301
# weighted avg       0.90      0.90      0.90      5301

# %%
tree = DecisionTreeClassifier(max_depth=3, criterion="gini", splitter="best")
model_test((tree,), X, y, tscv, scorers=scorers, labels=labels)
# Out:
# DecisionTreeClassifier(max_depth=3):
# CV with make_scorer(balanced_accuracy_score): 0.7830177142147934
#               precision    recall  f1-score   support
#
#   not_podium       0.94      0.95      0.94      4545
#       podium       0.66      0.62      0.64       756
#
#     accuracy                           0.90      5301
#    macro avg       0.80      0.78      0.79      5301
# weighted avg       0.90      0.90      0.90      5301

# %% [markdown]
# ## Random Forest

# %%
X_selected = X[
    [
        "positionGrid",
        "driverRef",
        "raceYear",
        "circuitLng",
        "driverWins",
        "q1",
        "driverExp",
        "driverRac",
        "driverAwa",
        "driverPac",
        "driverOvr",
    ]
]
random_forest = RandomForestClassifier(max_depth=8, n_estimators=440, criterion="gini")
model_test((random_forest,), X_selected, y, tscv, scorers=scorers, labels=labels)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=440):
# CV with make_scorer(balanced_accuracy_score): 0.7743942024034303
#               precision    recall  f1-score   support
#
#   not_podium       0.93      0.96      0.94      4545
#       podium       0.69      0.59      0.64       756
#
#     accuracy                           0.90      5301
#    macro avg       0.81      0.77      0.79      5301
# weighted avg       0.90      0.90      0.90      5301

# %%
random_forest = RandomForestClassifier(max_depth=8, n_estimators=440, criterion="gini")
model_test((random_forest,), X, y, tscv, scorers=scorers, labels=labels)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=440):
# CV with make_scorer(balanced_accuracy_score): 0.771638134377149
#               precision    recall  f1-score   support
#
#   not_podium       0.93      0.96      0.95      4545
#       podium       0.70      0.59      0.64       756
#
#     accuracy                           0.91      5301
#    macro avg       0.82      0.78      0.79      5301
# weighted avg       0.90      0.91      0.90      5301

# %% [markdown]
# ## Multilayer Perceptron

# %%
X_selected = X[
    [
        "carNumber",
        "positionGrid",
        "driverRef",
        "driverNumber",
        "driverNationality",
        "raceYear",
        "raceRound",
        "circuitRef",
        "circuitLocation",
        "circuitLat",
        "circuitAlt",
        "driverWins",
        "q1",
        "q2",
        "q3",
        "driverAgeToday",
        "driverAgeAtRace",
        "driverExp",
        "driverRac",
        "driverAwa",
        "driverPac",
        "driverOvr",
    ]
]
nn = MLPClassifier(activation="logistic", hidden_layer_sizes=(63, 30, 7))
model_test((nn,), X_selected, y, tscv, scorers=scorers, labels=labels)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(63, 30, 7)):
# CV with make_scorer(balanced_accuracy_score): 0.7881488493132391
#               precision    recall  f1-score   support
#
#   not_podium       0.94      0.95      0.94      4545
#       podium       0.68      0.62      0.65       756
#
#     accuracy                           0.90      5301
#    macro avg       0.81      0.78      0.80      5301
# weighted avg       0.90      0.90      0.90      5301

# %%
nn = MLPClassifier(activation="logistic", hidden_layer_sizes=(63, 30, 7))
model_test((nn,), X, y, tscv, scorers=scorers, labels=labels)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(63, 30, 7)):
# CV with make_scorer(balanced_accuracy_score): 0.8049762375179382
#               precision    recall  f1-score   support
#
#   not_podium       0.95      0.94      0.94      4545
#       podium       0.65      0.67      0.66       756
#
#     accuracy                           0.90      5301
#    macro avg       0.80      0.81      0.80      5301
# weighted avg       0.90      0.90      0.90      5301

# %% [markdown]
# ## Results

# %% [markdown]
# Based on the model in the previous section, i.e. with optimised attributes, performance has not improved.
#
# With all attributes, in this case, performance has not been improved.
