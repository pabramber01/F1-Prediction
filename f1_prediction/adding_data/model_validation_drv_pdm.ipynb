# %% [markdown]
# # Is podium

# %% [markdown]
# ## Dependencies

# %% [markdown]
# The dependencies used are as follows

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import make_scorer

import sys

sys.path.append("..")

from utils.visualization import model_test
from utils.custom_cvs import VariableTimeSeriesSplit
from utils.custom_scorers import balanced_accuracy_score

import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import warnings

warnings.simplefilter("ignore")

# %% [markdown]
# ## Initialization

# %% [markdown]
# We continue with the validation of the model that predicts the podium

# %%
df = pd.read_csv("../assets/data/processed/driver_ratings.csv")

mid_rc = df.groupby("raceYear")["raceRound"].max().to_numpy() // 2
get_half = lambda x: f'{x["raceYear"]}{x["raceRound"] <= mid_rc[x["raceYear"] - 2006]}'
instances_per_half = df.apply(get_half, axis=1).value_counts(sort=False).to_numpy()

n_splits = len(instances_per_half) - 10
max_train_size = [instances_per_half[i : 10 + i].sum() for i in range(n_splits)]
test_size = instances_per_half[10:].tolist()
tscv = VariableTimeSeriesSplit(
    n_splits=n_splits, max_train_size=max_train_size, test_size=test_size
)

scorers = [make_scorer(balanced_accuracy_score), "neg_mean_absolute_error"]
labels = np.array(["not_podium", "podium"])
podiums = df[df["positionFinal"].isin([1, 2, 3])][
    ["raceYear", "raceRound", "driverRef"]
]
podiums = podiums.groupby(by=["raceYear", "raceRound"]).agg({"driverRef": ",".join})

X = pd.read_csv("../assets/data/processed/driver_ratings_X.csv")
y = df.merge(podiums, how="left", on=["raceYear", "raceRound"], suffixes=("", "Podium"))
y = y.apply(lambda x: int(x["driverRef"] in x["driverRefPodium"]), axis=1)

# %% [markdown]
# ## K-Nearest Neighbors

# %%
X_selected = X[
    [
        "carNumber",
        "positionGrid",
        "driverRef",
        "driverNationality",
        "constructorRef",
        "raceYear",
        "driverWins",
        "constructorWins",
        "driverExp",
        "driverRac",
        "driverAwa",
        "driverPac",
        "driverOvr",
    ]
]
knn = KNeighborsClassifier(n_neighbors=24, metric="cosine", weights="distance")
model_test((knn,), X_selected, y, tscv, scorers=scorers, labels=labels)
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=24, weights='distance'):
# CV with make_scorer(balanced_accuracy_score): 0.7361656712393909
# CV with neg_mean_absolute_error: -0.11748909157577889
#               precision    recall  f1-score   support
#
#   not_podium       0.92      0.94      0.93      4545
#       podium       0.59      0.54      0.56       756
#
#     accuracy                           0.88      5301
#    macro avg       0.76      0.74      0.75      5301
# weighted avg       0.88      0.88      0.88      5301

# %%
knn = KNeighborsClassifier(n_neighbors=24, metric="cosine", weights="distance")
model_test((knn,), X, y, tscv, scorers=scorers, labels=labels)
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=24, weights='distance'):
# CV with make_scorer(balanced_accuracy_score): 0.7057907801950539
# CV with neg_mean_absolute_error: -0.11571287366832898
#               precision    recall  f1-score   support
#
#   not_podium       0.91      0.95      0.93      4545
#       podium       0.63      0.46      0.53       756
#
#     accuracy                           0.88      5301
#    macro avg       0.77      0.71      0.73      5301
# weighted avg       0.87      0.88      0.88      5301

# %% [markdown]
# ## Decision Tree

# %%
X_selected = X[
    [
        "positionGrid",
        "driverNationality",
        "constructorRef",
        "constructorNationality",
        "raceYear",
        "raceRound",
        "grandPrix",
        "circuitRef",
        "circuitLocation",
        "circuitCountry",
        "circuitLng",
        "driverWins",
        "constructorWins",
        "q3",
        "driverExp",
        "driverRac",
        "driverAwa",
        "driverPac",
        "driverOvr",
    ]
]
tree = DecisionTreeClassifier(max_depth=4, criterion="log_loss", splitter="best")
model_test((tree,), X_selected, y, tscv, scorers=scorers, labels=labels)
# Out:
# DecisionTreeClassifier(criterion='log_loss', max_depth=4):
# CV with make_scorer(balanced_accuracy_score): 0.7918585850462563
# CV with neg_mean_absolute_error: -0.10492809294426673
#               precision    recall  f1-score   support
#
#   not_podium       0.94      0.93      0.94      4545
#       podium       0.62      0.65      0.64       756
#
#     accuracy                           0.89      5301
#    macro avg       0.78      0.79      0.79      5301
# weighted avg       0.90      0.89      0.89      5301

# %%
tree = DecisionTreeClassifier(max_depth=4, criterion="log_loss", splitter="best")
model_test((tree,), X, y, tscv, scorers=scorers, labels=labels)
# Out:
# DecisionTreeClassifier(criterion='log_loss', max_depth=4):
# CV with make_scorer(balanced_accuracy_score): 0.7930192424232317
# CV with neg_mean_absolute_error: -0.10822213204179147
#               precision    recall  f1-score   support
#
#   not_podium       0.94      0.93      0.94      4545
#       podium       0.61      0.65      0.63       756
#
#     accuracy                           0.89      5301
#    macro avg       0.78      0.79      0.78      5301
# weighted avg       0.89      0.89      0.89      5301

# %% [markdown]
# ## Random Forest

# %%
X_selected = X[
    [
        "positionGrid",
        "driverNumber",
        "driverNationality",
        "constructorRef",
        "raceYear",
        "driverWins",
        "constructorWins",
        "q1",
        "driverAgeAtRace",
        "driverExp",
        "driverRac",
        "driverAwa",
        "driverPac",
        "driverOvr",
    ]
]
random_forest = RandomForestClassifier(
    max_depth=9, n_estimators=387, criterion="log_loss"
)
model_test((random_forest,), X_selected, y, tscv, scorers=scorers, labels=labels)
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=9, n_estimators=387):
# CV with make_scorer(balanced_accuracy_score): 0.7704376042094174
# CV with neg_mean_absolute_error: -0.09528976037129662
#               precision    recall  f1-score   support
#
#   not_podium       0.94      0.96      0.95      4545
#       podium       0.69      0.61      0.65       756
#
#     accuracy                           0.91      5301
#    macro avg       0.81      0.78      0.80      5301
# weighted avg       0.90      0.91      0.90      5301

# %%
random_forest = RandomForestClassifier(
    max_depth=9, n_estimators=387, criterion="log_loss"
)


model_test((random_forest,), X, y, tscv, scorers=scorers, labels=labels)
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=9, n_estimators=387):
# CV with make_scorer(balanced_accuracy_score): 0.7569291095330003
# CV with neg_mean_absolute_error: -0.09554320169271596
#               precision    recall  f1-score   support
#
#   not_podium       0.93      0.96      0.94      4545
#       podium       0.70      0.56      0.62       756
#
#     accuracy                           0.90      5301
#    macro avg       0.81      0.76      0.78      5301
# weighted avg       0.90      0.90      0.90      5301

# %% [markdown]
# ## Multilayer Perceptron

# %%
X_selected = X[
    [
        "positionGrid",
        "raceYear",
        "grandPrix",
        "circuitLocation",
        "circuitCountry",
        "circuitLat",
        "circuitAlt",
        "driverWins",
        "constructorWins",
        "q1",
        "q2",
        "driverExp",
        "driverRac",
        "driverAwa",
        "driverPac",
        "driverOvr",
    ]
]
nn = MLPClassifier(activation="logistic", hidden_layer_sizes=(71, 19, 76, 43, 40))
model_test((nn,), X_selected, y, tscv, scorers=scorers, labels=labels)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(71, 19, 76, 43, 40)):
# CV with make_scorer(balanced_accuracy_score): 0.7904836826814962
# CV with neg_mean_absolute_error: -0.09788165099217197
#               precision    recall  f1-score   support
#
#   not_podium       0.94      0.94      0.94      4545
#       podium       0.65      0.64      0.65       756
#
#     accuracy                           0.90      5301
#    macro avg       0.79      0.79      0.79      5301
# weighted avg       0.90      0.90      0.90      5301

# %%
nn = MLPClassifier(activation="logistic", hidden_layer_sizes=(71, 19, 76, 43, 40))
model_test((nn,), X, y, tscv, scorers=scorers, labels=labels)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(71, 19, 76, 43, 40)):
# CV with make_scorer(balanced_accuracy_score): 0.7981539446695257
# CV with neg_mean_absolute_error: -0.10258928428980209
#               precision    recall  f1-score   support
#
#   not_podium       0.94      0.93      0.94      4545
#       podium       0.62      0.67      0.64       756
#
#     accuracy                           0.90      5301
#    macro avg       0.78      0.80      0.79      5301
# weighted avg       0.90      0.90      0.90      5301

# %% [markdown]
# ## Results

# %% [markdown]
# Based on the model in the previous section, i.e. with optimised attributes, performance has not improved.
#
# With all attributes, in this case, performance has not been improved.
