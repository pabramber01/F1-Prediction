# %% [markdown]
# # Final position in variable interval

# %% [markdown]
# ## Dependencies

# %% [markdown]
# The dependencies used are as follows

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from xgboost import XGBClassifier, XGBRegressor, XGBRanker

import sys

sys.path.append("..")

from utils.visualization import model_prediction

import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import warnings

warnings.simplefilter("ignore")

# %% [markdown]
# ## Initialization

# %% [markdown]
# First we will do the prediction of the model that predicts the final position of each driver at a ±1 interval.

# %%
df_train = pd.read_csv("../assets/data/processed/final_model.csv")
df_train = df_train[df_train["raceYear"] >= 2019]

X_train = pd.read_csv("../assets/data/processed/final_model_X.csv")
X_train = X_train.iloc[-len(df_train) :]

y_train = df_train["positionFinal"]

# %%
df_test = pd.read_csv("../assets/data/processed/testing.csv")

columns = {"raceRound": df_test["raceRound"], "driverRef": df_test["driverRef"]}

X_test = pd.read_csv("../assets/data/processed/testing_X.csv")

y_test = df_test["positionFinal"]

# %% [markdown]
# ## K-Nearest Neighbors

# %%
attributes = [
    "positionGrid",
    "driverRef",
    "raceYear",
    "raceRound",
    "driverWins",
    "constructorWins",
    "driverAgeToday",
    "weatherCold",
    "weatherDry",
    "weatherWet",
    "circuitLaps",
    "driverExpYear",
    "driverExpRace",
    "driverPos2",
    "driverPos3",
    "driverPos4",
    "driverPos5",
    "driverPos8",
    "driverPos9",
    "driverPos12",
    "driverPos13",
    "driverPos17",
    "driverPos18",
    "driverRac",
    "driverPac",
]
knn = KNeighborsClassifier(n_neighbors=16, metric="manhattan", weights="distance")
model_prediction(
    knn,
    X_train[attributes],
    y_train,
    X_test[attributes],
    y_test,
    columns=columns,
    multiclass=True,
)
# Out:
# <div style='height: 550px'><style type="text/css">
# #T_14e7f_row0_col0, #T_14e7f_row0_col1, #T_14e7f_row0_col2, #T_14e7f_row0_col3, #T_14e7f_row1_col0, #T_14e7f_row1_col1, #T_14e7f_row1_col2, #T_14e7f_row1_col3, #T_14e7f_row6_col0, #T_14e7f_row6_col1, #T_14e7f_row6_col2, #T_14e7f_row6_col3, #T_14e7f_row8_col0, #T_14e7f_row8_col1, #T_14e7f_row8_col2, #T_14e7f_row8_col3, #T_14e7f_row12_col0, #T_14e7f_row12_col1, #T_14e7f_row12_col2, #T_14e7f_row12_col3, #T_14e7f_row19_col0, #T_14e7f_row19_col1, #T_14e7f_row19_col2, #T_14e7f_row19_col3, #T_14e7f_row20_col0, #T_14e7f_row20_col1, #T_14e7f_row20_col2, #T_14e7f_row20_col3, #T_14e7f_row21_col0, #T_14e7f_row21_col1, #T_14e7f_row21_col2, #T_14e7f_row21_col3, #T_14e7f_row28_col0, #T_14e7f_row28_col1, #T_14e7f_row28_col2, #T_14e7f_row28_col3, #T_14e7f_row30_col0, #T_14e7f_row30_col1, #T_14e7f_row30_col2, #T_14e7f_row30_col3, #T_14e7f_row31_col0, #T_14e7f_row31_col1, #T_14e7f_row31_col2, #T_14e7f_row31_col3, #T_14e7f_row32_col0, #T_14e7f_row32_col1, #T_14e7f_row32_col2, #T_14e7f_row32_col3, #T_14e7f_row33_col0, #T_14e7f_row33_col1, #T_14e7f_row33_col2, #T_14e7f_row33_col3, #T_14e7f_row34_col0, #T_14e7f_row34_col1, #T_14e7f_row34_col2, #T_14e7f_row34_col3, #T_14e7f_row40_col0, #T_14e7f_row40_col1, #T_14e7f_row40_col2, #T_14e7f_row40_col3, #T_14e7f_row43_col0, #T_14e7f_row43_col1, #T_14e7f_row43_col2, #T_14e7f_row43_col3, #T_14e7f_row51_col0, #T_14e7f_row51_col1, #T_14e7f_row51_col2, #T_14e7f_row51_col3, #T_14e7f_row53_col0, #T_14e7f_row53_col1, #T_14e7f_row53_col2, #T_14e7f_row53_col3, #T_14e7f_row54_col0, #T_14e7f_row54_col1, #T_14e7f_row54_col2, #T_14e7f_row54_col3, #T_14e7f_row56_col0, #T_14e7f_row56_col1, #T_14e7f_row56_col2, #T_14e7f_row56_col3, #T_14e7f_row59_col0, #T_14e7f_row59_col1, #T_14e7f_row59_col2, #T_14e7f_row59_col3, #T_14e7f_row60_col0, #T_14e7f_row60_col1, #T_14e7f_row60_col2, #T_14e7f_row60_col3, #T_14e7f_row62_col0, #T_14e7f_row62_col1, #T_14e7f_row62_col2, #T_14e7f_row62_col3, #T_14e7f_row63_col0, #T_14e7f_row63_col1, #T_14e7f_row63_col2, #T_14e7f_row63_col3, #T_14e7f_row64_col0, #T_14e7f_row64_col1, #T_14e7f_row64_col2, #T_14e7f_row64_col3, #T_14e7f_row74_col0, #T_14e7f_row74_col1, #T_14e7f_row74_col2, #T_14e7f_row74_col3, #T_14e7f_row75_col0, #T_14e7f_row75_col1, #T_14e7f_row75_col2, #T_14e7f_row75_col3 {
#   background-color: #1c542d;
# }
# #T_14e7f_row2_col0, #T_14e7f_row2_col1, #T_14e7f_row2_col2, #T_14e7f_row2_col3, #T_14e7f_row3_col0, #T_14e7f_row3_col1, #T_14e7f_row3_col2, #T_14e7f_row3_col3, #T_14e7f_row4_col0, #T_14e7f_row4_col1, #T_14e7f_row4_col2, #T_14e7f_row4_col3, #T_14e7f_row5_col0, #T_14e7f_row5_col1, #T_14e7f_row5_col2, #T_14e7f_row5_col3, #T_14e7f_row7_col0, #T_14e7f_row7_col1, #T_14e7f_row7_col2, #T_14e7f_row7_col3, #T_14e7f_row9_col0, #T_14e7f_row9_col1, #T_14e7f_row9_col2, #T_14e7f_row9_col3, #T_14e7f_row10_col0, #T_14e7f_row10_col1, #T_14e7f_row10_col2, #T_14e7f_row10_col3, #T_14e7f_row11_col0, #T_14e7f_row11_col1, #T_14e7f_row11_col2, #T_14e7f_row11_col3, #T_14e7f_row13_col0, #T_14e7f_row13_col1, #T_14e7f_row13_col2, #T_14e7f_row13_col3, #T_14e7f_row14_col0, #T_14e7f_row14_col1, #T_14e7f_row14_col2, #T_14e7f_row14_col3, #T_14e7f_row15_col0, #T_14e7f_row15_col1, #T_14e7f_row15_col2, #T_14e7f_row15_col3, #T_14e7f_row16_col0, #T_14e7f_row16_col1, #T_14e7f_row16_col2, #T_14e7f_row16_col3, #T_14e7f_row17_col0, #T_14e7f_row17_col1, #T_14e7f_row17_col2, #T_14e7f_row17_col3, #T_14e7f_row18_col0, #T_14e7f_row18_col1, #T_14e7f_row18_col2, #T_14e7f_row18_col3, #T_14e7f_row22_col0, #T_14e7f_row22_col1, #T_14e7f_row22_col2, #T_14e7f_row22_col3, #T_14e7f_row23_col0, #T_14e7f_row23_col1, #T_14e7f_row23_col2, #T_14e7f_row23_col3, #T_14e7f_row24_col0, #T_14e7f_row24_col1, #T_14e7f_row24_col2, #T_14e7f_row24_col3, #T_14e7f_row25_col0, #T_14e7f_row25_col1, #T_14e7f_row25_col2, #T_14e7f_row25_col3, #T_14e7f_row26_col0, #T_14e7f_row26_col1, #T_14e7f_row26_col2, #T_14e7f_row26_col3, #T_14e7f_row27_col0, #T_14e7f_row27_col1, #T_14e7f_row27_col2, #T_14e7f_row27_col3, #T_14e7f_row29_col0, #T_14e7f_row29_col1, #T_14e7f_row29_col2, #T_14e7f_row29_col3, #T_14e7f_row35_col0, #T_14e7f_row35_col1, #T_14e7f_row35_col2, #T_14e7f_row35_col3, #T_14e7f_row36_col0, #T_14e7f_row36_col1, #T_14e7f_row36_col2, #T_14e7f_row36_col3, #T_14e7f_row37_col0, #T_14e7f_row37_col1, #T_14e7f_row37_col2, #T_14e7f_row37_col3, #T_14e7f_row38_col0, #T_14e7f_row38_col1, #T_14e7f_row38_col2, #T_14e7f_row38_col3, #T_14e7f_row39_col0, #T_14e7f_row39_col1, #T_14e7f_row39_col2, #T_14e7f_row39_col3, #T_14e7f_row41_col0, #T_14e7f_row41_col1, #T_14e7f_row41_col2, #T_14e7f_row41_col3, #T_14e7f_row42_col0, #T_14e7f_row42_col1, #T_14e7f_row42_col2, #T_14e7f_row42_col3, #T_14e7f_row44_col0, #T_14e7f_row44_col1, #T_14e7f_row44_col2, #T_14e7f_row44_col3, #T_14e7f_row45_col0, #T_14e7f_row45_col1, #T_14e7f_row45_col2, #T_14e7f_row45_col3, #T_14e7f_row46_col0, #T_14e7f_row46_col1, #T_14e7f_row46_col2, #T_14e7f_row46_col3, #T_14e7f_row47_col0, #T_14e7f_row47_col1, #T_14e7f_row47_col2, #T_14e7f_row47_col3, #T_14e7f_row48_col0, #T_14e7f_row48_col1, #T_14e7f_row48_col2, #T_14e7f_row48_col3, #T_14e7f_row49_col0, #T_14e7f_row49_col1, #T_14e7f_row49_col2, #T_14e7f_row49_col3, #T_14e7f_row50_col0, #T_14e7f_row50_col1, #T_14e7f_row50_col2, #T_14e7f_row50_col3, #T_14e7f_row52_col0, #T_14e7f_row52_col1, #T_14e7f_row52_col2, #T_14e7f_row52_col3, #T_14e7f_row55_col0, #T_14e7f_row55_col1, #T_14e7f_row55_col2, #T_14e7f_row55_col3, #T_14e7f_row57_col0, #T_14e7f_row57_col1, #T_14e7f_row57_col2, #T_14e7f_row57_col3, #T_14e7f_row58_col0, #T_14e7f_row58_col1, #T_14e7f_row58_col2, #T_14e7f_row58_col3, #T_14e7f_row61_col0, #T_14e7f_row61_col1, #T_14e7f_row61_col2, #T_14e7f_row61_col3, #T_14e7f_row65_col0, #T_14e7f_row65_col1, #T_14e7f_row65_col2, #T_14e7f_row65_col3, #T_14e7f_row66_col0, #T_14e7f_row66_col1, #T_14e7f_row66_col2, #T_14e7f_row66_col3, #T_14e7f_row67_col0, #T_14e7f_row67_col1, #T_14e7f_row67_col2, #T_14e7f_row67_col3, #T_14e7f_row68_col0, #T_14e7f_row68_col1, #T_14e7f_row68_col2, #T_14e7f_row68_col3, #T_14e7f_row69_col0, #T_14e7f_row69_col1, #T_14e7f_row69_col2, #T_14e7f_row69_col3, #T_14e7f_row70_col0, #T_14e7f_row70_col1, #T_14e7f_row70_col2, #T_14e7f_row70_col3, #T_14e7f_row71_col0, #T_14e7f_row71_col1, #T_14e7f_row71_col2, #T_14e7f_row71_col3, #T_14e7f_row72_col0, #T_14e7f_row72_col1, #T_14e7f_row72_col2, #T_14e7f_row7 ...
#   background-color: #800000;
# }
# </style>
# <table id="T_14e7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14e7f_level0_col0" class="col_heading level0 col0" >raceRound</th>
#       <th id="T_14e7f_level0_col1" class="col_heading level0 col1" >driverRef</th>
#       <th id="T_14e7f_level0_col2" class="col_heading level0 col2" >positionFinal</th>
#       <th id="T_14e7f_level0_col3" class="col_heading level0 col3" >positionPred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14e7f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14e7f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_14e7f_row0_col1" class="data row0 col1" >max_verstappen</td>
#       <td id="T_14e7f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_14e7f_row0_col3" class="data row0 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_14e7f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14e7f_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_14e7f_row1_col1" class="data row1 col1" >perez</td>
#       <td id="T_14e7f_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_14e7f_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14e7f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_14e7f_row

# %% [markdown]
# ## Decision Tree

# %%
attributes = [
    "positionGrid",
    "driverNationality",
    "raceYear",
    "grandPrix",
    "raceTime",
    "circuitRef",
    "circuitLocation",
    "circuitCountry",
    "circuitLat",
    "circuitLng",
    "circuitAlt",
    "constructorWins",
    "q1",
    "q2",
    "q3",
    "weather",
    "weatherWarm",
    "weatherCold",
    "weatherDry",
    "weatherWet",
    "weatherCloudy",
    "circuitType",
    "circuitDirection",
    "circuitLength",
    "circuitLaps",
    "circuitDist",
    "qMin",
    "qMax",
    "qAvg",
    "driverAgeStarted",
    "driverPodiums",
    "driverPos3",
    "driverPos4",
    "driverPos5",
    "driverPos8",
    "driverPos10",
    "driverPos11",
    "driverPos12",
    "driverPos15",
    "driverPos17",
    "driverPos18",
    "driverPac",
]
tree = DecisionTreeClassifier(max_depth=4, criterion="gini", splitter="best")
model_prediction(
    tree,
    X_train[attributes],
    y_train,
    X_test[attributes],
    y_test,
    columns=columns,
    multiclass=True,
)
# Out:
# <div style='height: 550px'><style type="text/css">
# #T_bb022_row0_col0, #T_bb022_row0_col1, #T_bb022_row0_col2, #T_bb022_row0_col3, #T_bb022_row1_col0, #T_bb022_row1_col1, #T_bb022_row1_col2, #T_bb022_row1_col3, #T_bb022_row2_col0, #T_bb022_row2_col1, #T_bb022_row2_col2, #T_bb022_row2_col3, #T_bb022_row3_col0, #T_bb022_row3_col1, #T_bb022_row3_col2, #T_bb022_row3_col3, #T_bb022_row4_col0, #T_bb022_row4_col1, #T_bb022_row4_col2, #T_bb022_row4_col3, #T_bb022_row5_col0, #T_bb022_row5_col1, #T_bb022_row5_col2, #T_bb022_row5_col3, #T_bb022_row6_col0, #T_bb022_row6_col1, #T_bb022_row6_col2, #T_bb022_row6_col3, #T_bb022_row7_col0, #T_bb022_row7_col1, #T_bb022_row7_col2, #T_bb022_row7_col3, #T_bb022_row14_col0, #T_bb022_row14_col1, #T_bb022_row14_col2, #T_bb022_row14_col3, #T_bb022_row16_col0, #T_bb022_row16_col1, #T_bb022_row16_col2, #T_bb022_row16_col3, #T_bb022_row20_col0, #T_bb022_row20_col1, #T_bb022_row20_col2, #T_bb022_row20_col3, #T_bb022_row21_col0, #T_bb022_row21_col1, #T_bb022_row21_col2, #T_bb022_row21_col3, #T_bb022_row22_col0, #T_bb022_row22_col1, #T_bb022_row22_col2, #T_bb022_row22_col3, #T_bb022_row23_col0, #T_bb022_row23_col1, #T_bb022_row23_col2, #T_bb022_row23_col3, #T_bb022_row24_col0, #T_bb022_row24_col1, #T_bb022_row24_col2, #T_bb022_row24_col3, #T_bb022_row25_col0, #T_bb022_row25_col1, #T_bb022_row25_col2, #T_bb022_row25_col3, #T_bb022_row26_col0, #T_bb022_row26_col1, #T_bb022_row26_col2, #T_bb022_row26_col3, #T_bb022_row34_col0, #T_bb022_row34_col1, #T_bb022_row34_col2, #T_bb022_row34_col3, #T_bb022_row35_col0, #T_bb022_row35_col1, #T_bb022_row35_col2, #T_bb022_row35_col3, #T_bb022_row37_col0, #T_bb022_row37_col1, #T_bb022_row37_col2, #T_bb022_row37_col3, #T_bb022_row40_col0, #T_bb022_row40_col1, #T_bb022_row40_col2, #T_bb022_row40_col3, #T_bb022_row41_col0, #T_bb022_row41_col1, #T_bb022_row41_col2, #T_bb022_row41_col3, #T_bb022_row42_col0, #T_bb022_row42_col1, #T_bb022_row42_col2, #T_bb022_row42_col3, #T_bb022_row43_col0, #T_bb022_row43_col1, #T_bb022_row43_col2, #T_bb022_row43_col3, #T_bb022_row44_col0, #T_bb022_row44_col1, #T_bb022_row44_col2, #T_bb022_row44_col3, #T_bb022_row45_col0, #T_bb022_row45_col1, #T_bb022_row45_col2, #T_bb022_row45_col3, #T_bb022_row46_col0, #T_bb022_row46_col1, #T_bb022_row46_col2, #T_bb022_row46_col3, #T_bb022_row47_col0, #T_bb022_row47_col1, #T_bb022_row47_col2, #T_bb022_row47_col3, #T_bb022_row53_col0, #T_bb022_row53_col1, #T_bb022_row53_col2, #T_bb022_row53_col3, #T_bb022_row55_col0, #T_bb022_row55_col1, #T_bb022_row55_col2, #T_bb022_row55_col3, #T_bb022_row59_col0, #T_bb022_row59_col1, #T_bb022_row59_col2, #T_bb022_row59_col3, #T_bb022_row60_col0, #T_bb022_row60_col1, #T_bb022_row60_col2, #T_bb022_row60_col3, #T_bb022_row61_col0, #T_bb022_row61_col1, #T_bb022_row61_col2, #T_bb022_row61_col3, #T_bb022_row62_col0, #T_bb022_row62_col1, #T_bb022_row62_col2, #T_bb022_row62_col3, #T_bb022_row63_col0, #T_bb022_row63_col1, #T_bb022_row63_col2, #T_bb022_row63_col3, #T_bb022_row65_col0, #T_bb022_row65_col1, #T_bb022_row65_col2, #T_bb022_row65_col3, #T_bb022_row72_col0, #T_bb022_row72_col1, #T_bb022_row72_col2, #T_bb022_row72_col3, #T_bb022_row74_col0, #T_bb022_row74_col1, #T_bb022_row74_col2, #T_bb022_row74_col3, #T_bb022_row75_col0, #T_bb022_row75_col1, #T_bb022_row75_col2, #T_bb022_row75_col3, #T_bb022_row76_col0, #T_bb022_row76_col1, #T_bb022_row76_col2, #T_bb022_row76_col3 {
#   background-color: #1c542d;
# }
# #T_bb022_row8_col0, #T_bb022_row8_col1, #T_bb022_row8_col2, #T_bb022_row8_col3, #T_bb022_row9_col0, #T_bb022_row9_col1, #T_bb022_row9_col2, #T_bb022_row9_col3, #T_bb022_row10_col0, #T_bb022_row10_col1, #T_bb022_row10_col2, #T_bb022_row10_col3, #T_bb022_row11_col0, #T_bb022_row11_col1, #T_bb022_row11_col2, #T_bb022_row11_col3, #T_bb022_row12_col0, #T_bb022_row12_col1, #T_bb022_row12_col2, #T_bb022_row12_col3, #T_bb022_row13_col0, #T_bb022_row13_col1, #T_bb022_row13_col2, #T_bb022_row13_col3, #T_bb022_row15_col0, #T_bb022_row15_col1, #T_bb022_row15_col2, #T_bb022_row15_col3, #T_bb022_row17_col0, #T_bb022_row17_col1, #T_bb022_row17_col2, #T_bb022_row17_col3, #T_bb022_row18_col0, #T_bb022_row18_col1, #T_bb022_row18_col2, #T_bb022_row18_col3, #T_bb022_row19_col0, #T_bb022_row19_col1, #T_bb022_row19_col2, #T_bb022_row19_col3, #T_bb022_row27_col0, #T_bb022_row27_col1, #T_bb022_row27_col2, #T_bb022_row27_col3, #T_bb022_row28_col0, #T_bb022_row28_col1, #T_bb022_row28_col2, #T_bb022_row28_col3, #T_bb022_row29_col0, #T_bb022_row29_col1, #T_bb022_row29_col2, #T_bb022_row29_col3, #T_bb022_row30_col0, #T_bb022_row30_col1, #T_bb022_row30_col2, #T_bb022_row30_col3, #T_bb022_row31_col0, #T_bb022_row31_col1, #T_bb022_row31_col2, #T_bb022_row31_col3, #T_bb022_row32_col0, #T_bb022_row32_col1, #T_bb022_row32_col2, #T_bb022_row32_col3, #T_bb022_row33_col0, #T_bb022_row33_col1, #T_bb022_row33_col2, #T_bb022_row33_col3, #T_bb022_row36_col0, #T_bb022_row36_col1, #T_bb022_row36_col2, #T_bb022_row36_col3, #T_bb022_row38_col0, #T_bb022_row38_col1, #T_bb022_row38_col2, #T_bb022_row38_col3, #T_bb022_row39_col0, #T_bb022_row39_col1, #T_bb022_row39_col2, #T_bb022_row39_col3, #T_bb022_row48_col0, #T_bb022_row48_col1, #T_bb022_row48_col2, #T_bb022_row48_col3, #T_bb022_row49_col0, #T_bb022_row49_col1, #T_bb022_row49_col2, #T_bb022_row49_col3, #T_bb022_row50_col0, #T_bb022_row50_col1, #T_bb022_row50_col2, #T_bb022_row50_col3, #T_bb022_row51_col0, #T_bb022_row51_col1, #T_bb022_row51_col2, #T_bb022_row51_col3, #T_bb022_row52_col0, #T_bb022_row52_col1, #T_bb022_row52_col2, #T_bb022_row52_col3, #T_bb022_row54_col0, #T_bb022_row54_col1, #T_bb022_row54_col2, #T_bb022_row54_col3, #T_bb022_row56_col0, #T_bb022_row56_col1, #T_bb022_row56_col2, #T_bb022_row56_col3, #T_bb022_row57_col0, #T_bb022_row57_col1, #T_bb022_row57_col2, #T_bb022_row57_col3, #T_bb022_row58_col0, #T_bb022_row58_col1, #T_bb022_row58_col2, #T_bb022_row58_col3, #T_bb022_row64_col0, #T_bb022_row64_col1, #T_bb022_row64_col2, #T_bb022_row64_col3, #T_bb022_row66_col0, #T_bb022_row66_col1, #T_bb022_row66_col2, #T_bb022_row66_col3, #T_bb022_row67_col0, #T_bb022_row67_col1, #T_bb022_row67_col2, #T_bb022_row67_col3, #T_bb022_row68_col0, #T_bb022_row68_col1, #T_bb022_row68_col2, #T_bb022_row68_col3, #T_bb022_row69_col0, #T_bb022_row69_col1, #T_bb022_row69_col2, #T_bb022_row69_col3, #T_bb022_row70_col0, #T_bb022_row70_col1, #T_bb022_row70_col2, #T_bb022_row70_col3, #T_bb022_row71_col0, #T_bb022_row71_col1, #T_bb022_row71_col2, #T_bb022_row71_col3, #T_bb022_row73_col0, #T_bb022_row73_col1, #T_bb022_row73_col2, #T_bb022_row73_col3, #T_bb022_row77_col0, #T_bb022_row77_col1, #T_bb022_row77_col2, #T_bb022_row77_col3, #T_bb022_row78_col0, #T_bb022_row78_col1, #T_bb022_row78_col2, #T_bb022_row78_col3 {
#   background-color: #800000;
# }
# </style>
# <table id="T_bb022">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb022_level0_col0" class="col_heading level0 col0" >raceRound</th>
#       <th id="T_bb022_level0_col1" class="col_heading level0 col1" >driverRef</th>
#       <th id="T_bb022_level0_col2" class="col_heading level0 col2" >positionFinal</th>
#       <th id="T_bb022_level0_col3" class="col_heading level0 col3" >positionPred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb022_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb022_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_bb022_row0_col1" class="data row0 col1" >max_verstappen</td>
#       <td id="T_bb022_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_bb022_row0_col3" class="data row0 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bb022_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb022_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_bb022_row1_col1" class="data row1 col1" >perez</td>
#       <td id="T_bb022_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_bb022_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bb022_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bb022_row

# %% [markdown]
# ## Random Forest

# %%
attributes = [
    "positionGrid",
    "constructorRef",
    "raceYear",
    "circuitCountry",
    "driverWins",
    "weatherDry",
    "circuitType",
    "qMax",
    "driverExpYear",
    "driverPos3",
    "driverPos5",
    "driverPos7",
    "driverPos8",
    "driverPos13",
]
random_forest = RandomForestClassifier(
    max_depth=7, n_estimators=292, criterion="entropy"
)
model_prediction(
    random_forest,
    X_train[attributes],
    y_train,
    X_test[attributes],
    y_test,
    columns=columns,
    multiclass=True,
)
# Out:
# <div style='height: 550px'><style type="text/css">
# #T_1b55f_row0_col0, #T_1b55f_row0_col1, #T_1b55f_row0_col2, #T_1b55f_row0_col3, #T_1b55f_row2_col0, #T_1b55f_row2_col1, #T_1b55f_row2_col2, #T_1b55f_row2_col3, #T_1b55f_row3_col0, #T_1b55f_row3_col1, #T_1b55f_row3_col2, #T_1b55f_row3_col3, #T_1b55f_row4_col0, #T_1b55f_row4_col1, #T_1b55f_row4_col2, #T_1b55f_row4_col3, #T_1b55f_row5_col0, #T_1b55f_row5_col1, #T_1b55f_row5_col2, #T_1b55f_row5_col3, #T_1b55f_row6_col0, #T_1b55f_row6_col1, #T_1b55f_row6_col2, #T_1b55f_row6_col3, #T_1b55f_row7_col0, #T_1b55f_row7_col1, #T_1b55f_row7_col2, #T_1b55f_row7_col3, #T_1b55f_row11_col0, #T_1b55f_row11_col1, #T_1b55f_row11_col2, #T_1b55f_row11_col3, #T_1b55f_row12_col0, #T_1b55f_row12_col1, #T_1b55f_row12_col2, #T_1b55f_row12_col3, #T_1b55f_row14_col0, #T_1b55f_row14_col1, #T_1b55f_row14_col2, #T_1b55f_row14_col3, #T_1b55f_row20_col0, #T_1b55f_row20_col1, #T_1b55f_row20_col2, #T_1b55f_row20_col3, #T_1b55f_row21_col0, #T_1b55f_row21_col1, #T_1b55f_row21_col2, #T_1b55f_row21_col3, #T_1b55f_row22_col0, #T_1b55f_row22_col1, #T_1b55f_row22_col2, #T_1b55f_row22_col3, #T_1b55f_row23_col0, #T_1b55f_row23_col1, #T_1b55f_row23_col2, #T_1b55f_row23_col3, #T_1b55f_row25_col0, #T_1b55f_row25_col1, #T_1b55f_row25_col2, #T_1b55f_row25_col3, #T_1b55f_row31_col0, #T_1b55f_row31_col1, #T_1b55f_row31_col2, #T_1b55f_row31_col3, #T_1b55f_row32_col0, #T_1b55f_row32_col1, #T_1b55f_row32_col2, #T_1b55f_row32_col3, #T_1b55f_row34_col0, #T_1b55f_row34_col1, #T_1b55f_row34_col2, #T_1b55f_row34_col3, #T_1b55f_row40_col0, #T_1b55f_row40_col1, #T_1b55f_row40_col2, #T_1b55f_row40_col3, #T_1b55f_row41_col0, #T_1b55f_row41_col1, #T_1b55f_row41_col2, #T_1b55f_row41_col3, #T_1b55f_row42_col0, #T_1b55f_row42_col1, #T_1b55f_row42_col2, #T_1b55f_row42_col3, #T_1b55f_row44_col0, #T_1b55f_row44_col1, #T_1b55f_row44_col2, #T_1b55f_row44_col3, #T_1b55f_row45_col0, #T_1b55f_row45_col1, #T_1b55f_row45_col2, #T_1b55f_row45_col3, #T_1b55f_row47_col0, #T_1b55f_row47_col1, #T_1b55f_row47_col2, #T_1b55f_row47_col3, #T_1b55f_row51_col0, #T_1b55f_row51_col1, #T_1b55f_row51_col2, #T_1b55f_row51_col3, #T_1b55f_row52_col0, #T_1b55f_row52_col1, #T_1b55f_row52_col2, #T_1b55f_row52_col3, #T_1b55f_row54_col0, #T_1b55f_row54_col1, #T_1b55f_row54_col2, #T_1b55f_row54_col3, #T_1b55f_row59_col0, #T_1b55f_row59_col1, #T_1b55f_row59_col2, #T_1b55f_row59_col3, #T_1b55f_row60_col0, #T_1b55f_row60_col1, #T_1b55f_row60_col2, #T_1b55f_row60_col3, #T_1b55f_row61_col0, #T_1b55f_row61_col1, #T_1b55f_row61_col2, #T_1b55f_row61_col3, #T_1b55f_row62_col0, #T_1b55f_row62_col1, #T_1b55f_row62_col2, #T_1b55f_row62_col3, #T_1b55f_row74_col0, #T_1b55f_row74_col1, #T_1b55f_row74_col2, #T_1b55f_row74_col3, #T_1b55f_row75_col0, #T_1b55f_row75_col1, #T_1b55f_row75_col2, #T_1b55f_row75_col3 {
#   background-color: #1c542d;
# }
# #T_1b55f_row1_col0, #T_1b55f_row1_col1, #T_1b55f_row1_col2, #T_1b55f_row1_col3, #T_1b55f_row8_col0, #T_1b55f_row8_col1, #T_1b55f_row8_col2, #T_1b55f_row8_col3, #T_1b55f_row9_col0, #T_1b55f_row9_col1, #T_1b55f_row9_col2, #T_1b55f_row9_col3, #T_1b55f_row10_col0, #T_1b55f_row10_col1, #T_1b55f_row10_col2, #T_1b55f_row10_col3, #T_1b55f_row13_col0, #T_1b55f_row13_col1, #T_1b55f_row13_col2, #T_1b55f_row13_col3, #T_1b55f_row15_col0, #T_1b55f_row15_col1, #T_1b55f_row15_col2, #T_1b55f_row15_col3, #T_1b55f_row16_col0, #T_1b55f_row16_col1, #T_1b55f_row16_col2, #T_1b55f_row16_col3, #T_1b55f_row17_col0, #T_1b55f_row17_col1, #T_1b55f_row17_col2, #T_1b55f_row17_col3, #T_1b55f_row18_col0, #T_1b55f_row18_col1, #T_1b55f_row18_col2, #T_1b55f_row18_col3, #T_1b55f_row19_col0, #T_1b55f_row19_col1, #T_1b55f_row19_col2, #T_1b55f_row19_col3, #T_1b55f_row24_col0, #T_1b55f_row24_col1, #T_1b55f_row24_col2, #T_1b55f_row24_col3, #T_1b55f_row26_col0, #T_1b55f_row26_col1, #T_1b55f_row26_col2, #T_1b55f_row26_col3, #T_1b55f_row27_col0, #T_1b55f_row27_col1, #T_1b55f_row27_col2, #T_1b55f_row27_col3, #T_1b55f_row28_col0, #T_1b55f_row28_col1, #T_1b55f_row28_col2, #T_1b55f_row28_col3, #T_1b55f_row29_col0, #T_1b55f_row29_col1, #T_1b55f_row29_col2, #T_1b55f_row29_col3, #T_1b55f_row30_col0, #T_1b55f_row30_col1, #T_1b55f_row30_col2, #T_1b55f_row30_col3, #T_1b55f_row33_col0, #T_1b55f_row33_col1, #T_1b55f_row33_col2, #T_1b55f_row33_col3, #T_1b55f_row35_col0, #T_1b55f_row35_col1, #T_1b55f_row35_col2, #T_1b55f_row35_col3, #T_1b55f_row36_col0, #T_1b55f_row36_col1, #T_1b55f_row36_col2, #T_1b55f_row36_col3, #T_1b55f_row37_col0, #T_1b55f_row37_col1, #T_1b55f_row37_col2, #T_1b55f_row37_col3, #T_1b55f_row38_col0, #T_1b55f_row38_col1, #T_1b55f_row38_col2, #T_1b55f_row38_col3, #T_1b55f_row39_col0, #T_1b55f_row39_col1, #T_1b55f_row39_col2, #T_1b55f_row39_col3, #T_1b55f_row43_col0, #T_1b55f_row43_col1, #T_1b55f_row43_col2, #T_1b55f_row43_col3, #T_1b55f_row46_col0, #T_1b55f_row46_col1, #T_1b55f_row46_col2, #T_1b55f_row46_col3, #T_1b55f_row48_col0, #T_1b55f_row48_col1, #T_1b55f_row48_col2, #T_1b55f_row48_col3, #T_1b55f_row49_col0, #T_1b55f_row49_col1, #T_1b55f_row49_col2, #T_1b55f_row49_col3, #T_1b55f_row50_col0, #T_1b55f_row50_col1, #T_1b55f_row50_col2, #T_1b55f_row50_col3, #T_1b55f_row53_col0, #T_1b55f_row53_col1, #T_1b55f_row53_col2, #T_1b55f_row53_col3, #T_1b55f_row55_col0, #T_1b55f_row55_col1, #T_1b55f_row55_col2, #T_1b55f_row55_col3, #T_1b55f_row56_col0, #T_1b55f_row56_col1, #T_1b55f_row56_col2, #T_1b55f_row56_col3, #T_1b55f_row57_col0, #T_1b55f_row57_col1, #T_1b55f_row57_col2, #T_1b55f_row57_col3, #T_1b55f_row58_col0, #T_1b55f_row58_col1, #T_1b55f_row58_col2, #T_1b55f_row58_col3, #T_1b55f_row63_col0, #T_1b55f_row63_col1, #T_1b55f_row63_col2, #T_1b55f_row63_col3, #T_1b55f_row64_col0, #T_1b55f_row64_col1, #T_1b55f_row64_col2, #T_1b55f_row64_col3, #T_1b55f_row65_col0, #T_1b55f_row65_col1, #T_1b55f_row65_col2, #T_1b55f_row65_col3, #T_1b55f_row66_col0, #T_1b55f_row66_col1, #T_1b55f_row66_col2, #T_1b55f_row66_col3, #T_1b55f_row67_col0, #T_1b55f_row67_col1, #T_1b55f_row67_col2, #T_1b55f_row67_col3, #T_1b55f_row68_col0, #T_1b55f_row68_col1, #T_1b55f_row68_col2, #T_1b55f_row68_col3, #T_1b55f_row69_col0, #T_1b55f_row69_col1, #T_1b55f_row69_col2, #T_1b55f_row69_col3, #T_1b55f_row70_col0, #T_1b55f_row70_col1, #T_1b55f_row70_col2, #T_1b55f_row70_col3, #T_1b55f_row71_col0, #T_1b55f_row71_col1, #T_1b55f_row71_col2, #T_1b55f_row71_col3, #T_1b55f_row72_col0, #T_1b55f_row72_col1, #T_1b55f_row72_col2, #T_1b55f_row72_col3, #T_1b55f_row73_col0, #T_1b55f_row73_col1, #T_1b55f_row73_col2, #T_1b55f_row73_col3, #T_1b55f_row76_col0, #T_1b55f_row76_col1, #T_1b55f_row76_col2, #T_1b55f_row76_col3, #T_1b55f_row77_col0, #T_1b55f_row77_col1, #T_1b55f_row77_col2, #T_1b55f_row77_col3, #T_1b55f_row78_col0, #T_1b55f_row78_col1, #T_1b55f_row78_col2, #T_1b55f_row78_col3 {
#   background-color: #800000;
# }
# </style>
# <table id="T_1b55f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b55f_level0_col0" class="col_heading level0 col0" >raceRound</th>
#       <th id="T_1b55f_level0_col1" class="col_heading level0 col1" >driverRef</th>
#       <th id="T_1b55f_level0_col2" class="col_heading level0 col2" >positionFinal</th>
#       <th id="T_1b55f_level0_col3" class="col_heading level0 col3" >positionPred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b55f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b55f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_1b55f_row0_col1" class="data row0 col1" >max_verstappen</td>
#       <td id="T_1b55f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_1b55f_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1b55f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b55f_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_1b55f_row1_col1" class="data row1 col1" >perez</td>
#       <td id="T_1b55f_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_1b55f_row1_col3" class="data row1 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1b55f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b55f_row

# %% [markdown]
# ## Multilayer Perceptron

# %%
attributes = [
    "positionGrid",
    "driverNumber",
    "constructorNationality",
    "circuitCountry",
    "circuitLat",
    "circuitLng",
    "driverWins",
    "weatherWarm",
    "weatherCloudy",
    "circuitLaps",
    "qMin",
    "driverPodiums",
    "driverPos3",
    "driverPos6",
    "driverPos9",
    "driverPos15",
    "driverPos17",
    "driverRac",
    "driverAwa",
]
nn = MLPClassifier(activation="logistic", hidden_layer_sizes=(47, 25))
model_prediction(
    nn,
    X_train[attributes],
    y_train,
    X_test[attributes],
    y_test,
    columns=columns,
    multiclass=True,
)
# Out:
# <div style='height: 550px'><style type="text/css">
# #T_37450_row0_col0, #T_37450_row0_col1, #T_37450_row0_col2, #T_37450_row0_col3, #T_37450_row2_col0, #T_37450_row2_col1, #T_37450_row2_col2, #T_37450_row2_col3, #T_37450_row3_col0, #T_37450_row3_col1, #T_37450_row3_col2, #T_37450_row3_col3, #T_37450_row5_col0, #T_37450_row5_col1, #T_37450_row5_col2, #T_37450_row5_col3, #T_37450_row6_col0, #T_37450_row6_col1, #T_37450_row6_col2, #T_37450_row6_col3, #T_37450_row7_col0, #T_37450_row7_col1, #T_37450_row7_col2, #T_37450_row7_col3, #T_37450_row12_col0, #T_37450_row12_col1, #T_37450_row12_col2, #T_37450_row12_col3, #T_37450_row13_col0, #T_37450_row13_col1, #T_37450_row13_col2, #T_37450_row13_col3, #T_37450_row14_col0, #T_37450_row14_col1, #T_37450_row14_col2, #T_37450_row14_col3, #T_37450_row20_col0, #T_37450_row20_col1, #T_37450_row20_col2, #T_37450_row20_col3, #T_37450_row21_col0, #T_37450_row21_col1, #T_37450_row21_col2, #T_37450_row21_col3, #T_37450_row22_col0, #T_37450_row22_col1, #T_37450_row22_col2, #T_37450_row22_col3, #T_37450_row24_col0, #T_37450_row24_col1, #T_37450_row24_col2, #T_37450_row24_col3, #T_37450_row25_col0, #T_37450_row25_col1, #T_37450_row25_col2, #T_37450_row25_col3, #T_37450_row32_col0, #T_37450_row32_col1, #T_37450_row32_col2, #T_37450_row32_col3, #T_37450_row33_col0, #T_37450_row33_col1, #T_37450_row33_col2, #T_37450_row33_col3, #T_37450_row34_col0, #T_37450_row34_col1, #T_37450_row34_col2, #T_37450_row34_col3, #T_37450_row40_col0, #T_37450_row40_col1, #T_37450_row40_col2, #T_37450_row40_col3, #T_37450_row41_col0, #T_37450_row41_col1, #T_37450_row41_col2, #T_37450_row41_col3, #T_37450_row46_col0, #T_37450_row46_col1, #T_37450_row46_col2, #T_37450_row46_col3, #T_37450_row51_col0, #T_37450_row51_col1, #T_37450_row51_col2, #T_37450_row51_col3, #T_37450_row59_col0, #T_37450_row59_col1, #T_37450_row59_col2, #T_37450_row59_col3, #T_37450_row60_col0, #T_37450_row60_col1, #T_37450_row60_col2, #T_37450_row60_col3, #T_37450_row63_col0, #T_37450_row63_col1, #T_37450_row63_col2, #T_37450_row63_col3, #T_37450_row64_col0, #T_37450_row64_col1, #T_37450_row64_col2, #T_37450_row64_col3, #T_37450_row65_col0, #T_37450_row65_col1, #T_37450_row65_col2, #T_37450_row65_col3, #T_37450_row72_col0, #T_37450_row72_col1, #T_37450_row72_col2, #T_37450_row72_col3, #T_37450_row73_col0, #T_37450_row73_col1, #T_37450_row73_col2, #T_37450_row73_col3, #T_37450_row75_col0, #T_37450_row75_col1, #T_37450_row75_col2, #T_37450_row75_col3 {
#   background-color: #1c542d;
# }
# #T_37450_row1_col0, #T_37450_row1_col1, #T_37450_row1_col2, #T_37450_row1_col3, #T_37450_row4_col0, #T_37450_row4_col1, #T_37450_row4_col2, #T_37450_row4_col3, #T_37450_row8_col0, #T_37450_row8_col1, #T_37450_row8_col2, #T_37450_row8_col3, #T_37450_row9_col0, #T_37450_row9_col1, #T_37450_row9_col2, #T_37450_row9_col3, #T_37450_row10_col0, #T_37450_row10_col1, #T_37450_row10_col2, #T_37450_row10_col3, #T_37450_row11_col0, #T_37450_row11_col1, #T_37450_row11_col2, #T_37450_row11_col3, #T_37450_row15_col0, #T_37450_row15_col1, #T_37450_row15_col2, #T_37450_row15_col3, #T_37450_row16_col0, #T_37450_row16_col1, #T_37450_row16_col2, #T_37450_row16_col3, #T_37450_row17_col0, #T_37450_row17_col1, #T_37450_row17_col2, #T_37450_row17_col3, #T_37450_row18_col0, #T_37450_row18_col1, #T_37450_row18_col2, #T_37450_row18_col3, #T_37450_row19_col0, #T_37450_row19_col1, #T_37450_row19_col2, #T_37450_row19_col3, #T_37450_row23_col0, #T_37450_row23_col1, #T_37450_row23_col2, #T_37450_row23_col3, #T_37450_row26_col0, #T_37450_row26_col1, #T_37450_row26_col2, #T_37450_row26_col3, #T_37450_row27_col0, #T_37450_row27_col1, #T_37450_row27_col2, #T_37450_row27_col3, #T_37450_row28_col0, #T_37450_row28_col1, #T_37450_row28_col2, #T_37450_row28_col3, #T_37450_row29_col0, #T_37450_row29_col1, #T_37450_row29_col2, #T_37450_row29_col3, #T_37450_row30_col0, #T_37450_row30_col1, #T_37450_row30_col2, #T_37450_row30_col3, #T_37450_row31_col0, #T_37450_row31_col1, #T_37450_row31_col2, #T_37450_row31_col3, #T_37450_row35_col0, #T_37450_row35_col1, #T_37450_row35_col2, #T_37450_row35_col3, #T_37450_row36_col0, #T_37450_row36_col1, #T_37450_row36_col2, #T_37450_row36_col3, #T_37450_row37_col0, #T_37450_row37_col1, #T_37450_row37_col2, #T_37450_row37_col3, #T_37450_row38_col0, #T_37450_row38_col1, #T_37450_row38_col2, #T_37450_row38_col3, #T_37450_row39_col0, #T_37450_row39_col1, #T_37450_row39_col2, #T_37450_row39_col3, #T_37450_row42_col0, #T_37450_row42_col1, #T_37450_row42_col2, #T_37450_row42_col3, #T_37450_row43_col0, #T_37450_row43_col1, #T_37450_row43_col2, #T_37450_row43_col3, #T_37450_row44_col0, #T_37450_row44_col1, #T_37450_row44_col2, #T_37450_row44_col3, #T_37450_row45_col0, #T_37450_row45_col1, #T_37450_row45_col2, #T_37450_row45_col3, #T_37450_row47_col0, #T_37450_row47_col1, #T_37450_row47_col2, #T_37450_row47_col3, #T_37450_row48_col0, #T_37450_row48_col1, #T_37450_row48_col2, #T_37450_row48_col3, #T_37450_row49_col0, #T_37450_row49_col1, #T_37450_row49_col2, #T_37450_row49_col3, #T_37450_row50_col0, #T_37450_row50_col1, #T_37450_row50_col2, #T_37450_row50_col3, #T_37450_row52_col0, #T_37450_row52_col1, #T_37450_row52_col2, #T_37450_row52_col3, #T_37450_row53_col0, #T_37450_row53_col1, #T_37450_row53_col2, #T_37450_row53_col3, #T_37450_row54_col0, #T_37450_row54_col1, #T_37450_row54_col2, #T_37450_row54_col3, #T_37450_row55_col0, #T_37450_row55_col1, #T_37450_row55_col2, #T_37450_row55_col3, #T_37450_row56_col0, #T_37450_row56_col1, #T_37450_row56_col2, #T_37450_row56_col3, #T_37450_row57_col0, #T_37450_row57_col1, #T_37450_row57_col2, #T_37450_row57_col3, #T_37450_row58_col0, #T_37450_row58_col1, #T_37450_row58_col2, #T_37450_row58_col3, #T_37450_row61_col0, #T_37450_row61_col1, #T_37450_row61_col2, #T_37450_row61_col3, #T_37450_row62_col0, #T_37450_row62_col1, #T_37450_row62_col2, #T_37450_row62_col3, #T_37450_row66_col0, #T_37450_row66_col1, #T_37450_row66_col2, #T_37450_row66_col3, #T_37450_row67_col0, #T_37450_row67_col1, #T_37450_row67_col2, #T_37450_row67_col3, #T_37450_row68_col0, #T_37450_row68_col1, #T_37450_row68_col2, #T_37450_row68_col3, #T_37450_row69_col0, #T_37450_row69_col1, #T_37450_row69_col2, #T_37450_row69_col3, #T_37450_row70_col0, #T_37450_row70_col1, #T_37450_row70_col2, #T_37450_row70_col3, #T_37450_row71_col0, #T_37450_row71_col1, #T_37450_row71_col2, #T_37450_row71_col3, #T_37450_row74_col0, #T_37450_row74_col1, #T_37450_row74_col2, #T_37450_row74_col3, #T_37450_row76_col0, #T_37450_row76_col1, #T_37450_row76_col2, #T_37 ...
#   background-color: #800000;
# }
# </style>
# <table id="T_37450">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37450_level0_col0" class="col_heading level0 col0" >raceRound</th>
#       <th id="T_37450_level0_col1" class="col_heading level0 col1" >driverRef</th>
#       <th id="T_37450_level0_col2" class="col_heading level0 col2" >positionFinal</th>
#       <th id="T_37450_level0_col3" class="col_heading level0 col3" >positionPred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37450_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37450_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_37450_row0_col1" class="data row0 col1" >max_verstappen</td>
#       <td id="T_37450_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_37450_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_37450_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_37450_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_37450_row1_col1" class="data row1 col1" >perez</td>
#       <td id="T_37450_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_37450_row1_col3" class="data row1 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_37450_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_37450_row

# %% [markdown]
# ## XGBClassifier

# %%
attributes = [
    "carNumber",
    "positionGrid",
    "driverRef",
    "driverNumber",
    "constructorRef",
    "constructorNationality",
    "raceYear",
    "raceRound",
    "grandPrix",
    "raceTime",
    "circuitRef",
    "circuitLat",
    "circuitLng",
    "circuitAlt",
    "driverWins",
    "constructorWins",
    "q3",
    "driverAgeAtRace",
    "weatherWarm",
    "weatherDry",
    "circuitType",
    "circuitDirection",
    "circuitLength",
    "qMin",
    "qMax",
    "qAvg",
    "driverPodiums",
    "driverPos2",
    "driverPos5",
    "driverPos7",
    "driverPos8",
    "driverPos9",
    "driverPos10",
    "driverPos15",
    "driverPos17",
    "driverExp",
    "driverRac",
    "driverOvr",
]
model = XGBClassifier(
    objective="multi:softmax",
    learning_rate=0.08582939395916275,
    n_estimators=334,
    max_depth=14,
    min_child_weight=1,
    gamma=0.2007647640582077,
    subsample=0.8028533603905642,
    colsample_bytree=0.7154227055164297,
    reg_alpha=4,
    reg_lambda=55,
)
model_prediction(
    model,
    X_train[attributes],
    y_train - 1,
    X_test[attributes],
    y_test - 1,
    columns=columns,
    multiclass=True,
)
# Out:
# <div style='height: 550px'><style type="text/css">
# #T_8a772_row0_col0, #T_8a772_row0_col1, #T_8a772_row0_col2, #T_8a772_row0_col3, #T_8a772_row2_col0, #T_8a772_row2_col1, #T_8a772_row2_col2, #T_8a772_row2_col3, #T_8a772_row3_col0, #T_8a772_row3_col1, #T_8a772_row3_col2, #T_8a772_row3_col3, #T_8a772_row5_col0, #T_8a772_row5_col1, #T_8a772_row5_col2, #T_8a772_row5_col3, #T_8a772_row12_col0, #T_8a772_row12_col1, #T_8a772_row12_col2, #T_8a772_row12_col3, #T_8a772_row16_col0, #T_8a772_row16_col1, #T_8a772_row16_col2, #T_8a772_row16_col3, #T_8a772_row20_col0, #T_8a772_row20_col1, #T_8a772_row20_col2, #T_8a772_row20_col3, #T_8a772_row21_col0, #T_8a772_row21_col1, #T_8a772_row21_col2, #T_8a772_row21_col3, #T_8a772_row22_col0, #T_8a772_row22_col1, #T_8a772_row22_col2, #T_8a772_row22_col3, #T_8a772_row23_col0, #T_8a772_row23_col1, #T_8a772_row23_col2, #T_8a772_row23_col3, #T_8a772_row25_col0, #T_8a772_row25_col1, #T_8a772_row25_col2, #T_8a772_row25_col3, #T_8a772_row30_col0, #T_8a772_row30_col1, #T_8a772_row30_col2, #T_8a772_row30_col3, #T_8a772_row32_col0, #T_8a772_row32_col1, #T_8a772_row32_col2, #T_8a772_row32_col3, #T_8a772_row34_col0, #T_8a772_row34_col1, #T_8a772_row34_col2, #T_8a772_row34_col3, #T_8a772_row40_col0, #T_8a772_row40_col1, #T_8a772_row40_col2, #T_8a772_row40_col3, #T_8a772_row41_col0, #T_8a772_row41_col1, #T_8a772_row41_col2, #T_8a772_row41_col3, #T_8a772_row42_col0, #T_8a772_row42_col1, #T_8a772_row42_col2, #T_8a772_row42_col3, #T_8a772_row43_col0, #T_8a772_row43_col1, #T_8a772_row43_col2, #T_8a772_row43_col3, #T_8a772_row44_col0, #T_8a772_row44_col1, #T_8a772_row44_col2, #T_8a772_row44_col3, #T_8a772_row45_col0, #T_8a772_row45_col1, #T_8a772_row45_col2, #T_8a772_row45_col3, #T_8a772_row47_col0, #T_8a772_row47_col1, #T_8a772_row47_col2, #T_8a772_row47_col3, #T_8a772_row50_col0, #T_8a772_row50_col1, #T_8a772_row50_col2, #T_8a772_row50_col3, #T_8a772_row53_col0, #T_8a772_row53_col1, #T_8a772_row53_col2, #T_8a772_row53_col3, #T_8a772_row54_col0, #T_8a772_row54_col1, #T_8a772_row54_col2, #T_8a772_row54_col3, #T_8a772_row55_col0, #T_8a772_row55_col1, #T_8a772_row55_col2, #T_8a772_row55_col3, #T_8a772_row59_col0, #T_8a772_row59_col1, #T_8a772_row59_col2, #T_8a772_row59_col3, #T_8a772_row60_col0, #T_8a772_row60_col1, #T_8a772_row60_col2, #T_8a772_row60_col3, #T_8a772_row62_col0, #T_8a772_row62_col1, #T_8a772_row62_col2, #T_8a772_row62_col3, #T_8a772_row64_col0, #T_8a772_row64_col1, #T_8a772_row64_col2, #T_8a772_row64_col3, #T_8a772_row68_col0, #T_8a772_row68_col1, #T_8a772_row68_col2, #T_8a772_row68_col3, #T_8a772_row72_col0, #T_8a772_row72_col1, #T_8a772_row72_col2, #T_8a772_row72_col3, #T_8a772_row73_col0, #T_8a772_row73_col1, #T_8a772_row73_col2, #T_8a772_row73_col3, #T_8a772_row75_col0, #T_8a772_row75_col1, #T_8a772_row75_col2, #T_8a772_row75_col3 {
#   background-color: #1c542d;
# }
# #T_8a772_row1_col0, #T_8a772_row1_col1, #T_8a772_row1_col2, #T_8a772_row1_col3, #T_8a772_row4_col0, #T_8a772_row4_col1, #T_8a772_row4_col2, #T_8a772_row4_col3, #T_8a772_row6_col0, #T_8a772_row6_col1, #T_8a772_row6_col2, #T_8a772_row6_col3, #T_8a772_row7_col0, #T_8a772_row7_col1, #T_8a772_row7_col2, #T_8a772_row7_col3, #T_8a772_row8_col0, #T_8a772_row8_col1, #T_8a772_row8_col2, #T_8a772_row8_col3, #T_8a772_row9_col0, #T_8a772_row9_col1, #T_8a772_row9_col2, #T_8a772_row9_col3, #T_8a772_row10_col0, #T_8a772_row10_col1, #T_8a772_row10_col2, #T_8a772_row10_col3, #T_8a772_row11_col0, #T_8a772_row11_col1, #T_8a772_row11_col2, #T_8a772_row11_col3, #T_8a772_row13_col0, #T_8a772_row13_col1, #T_8a772_row13_col2, #T_8a772_row13_col3, #T_8a772_row14_col0, #T_8a772_row14_col1, #T_8a772_row14_col2, #T_8a772_row14_col3, #T_8a772_row15_col0, #T_8a772_row15_col1, #T_8a772_row15_col2, #T_8a772_row15_col3, #T_8a772_row17_col0, #T_8a772_row17_col1, #T_8a772_row17_col2, #T_8a772_row17_col3, #T_8a772_row18_col0, #T_8a772_row18_col1, #T_8a772_row18_col2, #T_8a772_row18_col3, #T_8a772_row19_col0, #T_8a772_row19_col1, #T_8a772_row19_col2, #T_8a772_row19_col3, #T_8a772_row24_col0, #T_8a772_row24_col1, #T_8a772_row24_col2, #T_8a772_row24_col3, #T_8a772_row26_col0, #T_8a772_row26_col1, #T_8a772_row26_col2, #T_8a772_row26_col3, #T_8a772_row27_col0, #T_8a772_row27_col1, #T_8a772_row27_col2, #T_8a772_row27_col3, #T_8a772_row28_col0, #T_8a772_row28_col1, #T_8a772_row28_col2, #T_8a772_row28_col3, #T_8a772_row29_col0, #T_8a772_row29_col1, #T_8a772_row29_col2, #T_8a772_row29_col3, #T_8a772_row31_col0, #T_8a772_row31_col1, #T_8a772_row31_col2, #T_8a772_row31_col3, #T_8a772_row33_col0, #T_8a772_row33_col1, #T_8a772_row33_col2, #T_8a772_row33_col3, #T_8a772_row35_col0, #T_8a772_row35_col1, #T_8a772_row35_col2, #T_8a772_row35_col3, #T_8a772_row36_col0, #T_8a772_row36_col1, #T_8a772_row36_col2, #T_8a772_row36_col3, #T_8a772_row37_col0, #T_8a772_row37_col1, #T_8a772_row37_col2, #T_8a772_row37_col3, #T_8a772_row38_col0, #T_8a772_row38_col1, #T_8a772_row38_col2, #T_8a772_row38_col3, #T_8a772_row39_col0, #T_8a772_row39_col1, #T_8a772_row39_col2, #T_8a772_row39_col3, #T_8a772_row46_col0, #T_8a772_row46_col1, #T_8a772_row46_col2, #T_8a772_row46_col3, #T_8a772_row48_col0, #T_8a772_row48_col1, #T_8a772_row48_col2, #T_8a772_row48_col3, #T_8a772_row49_col0, #T_8a772_row49_col1, #T_8a772_row49_col2, #T_8a772_row49_col3, #T_8a772_row51_col0, #T_8a772_row51_col1, #T_8a772_row51_col2, #T_8a772_row51_col3, #T_8a772_row52_col0, #T_8a772_row52_col1, #T_8a772_row52_col2, #T_8a772_row52_col3, #T_8a772_row56_col0, #T_8a772_row56_col1, #T_8a772_row56_col2, #T_8a772_row56_col3, #T_8a772_row57_col0, #T_8a772_row57_col1, #T_8a772_row57_col2, #T_8a772_row57_col3, #T_8a772_row58_col0, #T_8a772_row58_col1, #T_8a772_row58_col2, #T_8a772_row58_col3, #T_8a772_row61_col0, #T_8a772_row61_col1, #T_8a772_row61_col2, #T_8a772_row61_col3, #T_8a772_row63_col0, #T_8a772_row63_col1, #T_8a772_row63_col2, #T_8a772_row63_col3, #T_8a772_row65_col0, #T_8a772_row65_col1, #T_8a772_row65_col2, #T_8a772_row65_col3, #T_8a772_row66_col0, #T_8a772_row66_col1, #T_8a772_row66_col2, #T_8a772_row66_col3, #T_8a772_row67_col0, #T_8a772_row67_col1, #T_8a772_row67_col2, #T_8a772_row67_col3, #T_8a772_row69_col0, #T_8a772_row69_col1, #T_8a772_row69_col2, #T_8a772_row69_col3, #T_8a772_row70_col0, #T_8a772_row70_col1, #T_8a772_row70_col2, #T_8a772_row70_col3, #T_8a772_row71_col0, #T_8a772_row71_col1, #T_8a772_row71_col2, #T_8a772_row71_col3, #T_8a772_row74_col0, #T_8a772_row74_col1, #T_8a772_row74_col2, #T_8a772_row74_col3, #T_8a772_row76_col0, #T_8a772_row76_col1, #T_8a772_row76_col2, #T_8a772_row76_col3, #T_8a772_row77_col0, #T_8a772_row77_col1, #T_8a772_row77_col2, #T_8a772_row77_col3, #T_8a772_row78_col0, #T_8a772_row78_col1, #T_8a772_row78_col2, #T_8a772_row78_col3 {
#   background-color: #800000;
# }
# </style>
# <table id="T_8a772">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a772_level0_col0" class="col_heading level0 col0" >raceRound</th>
#       <th id="T_8a772_level0_col1" class="col_heading level0 col1" >driverRef</th>
#       <th id="T_8a772_level0_col2" class="col_heading level0 col2" >positionFinal</th>
#       <th id="T_8a772_level0_col3" class="col_heading level0 col3" >positionPred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a772_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a772_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_8a772_row0_col1" class="data row0 col1" >max_verstappen</td>
#       <td id="T_8a772_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_8a772_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8a772_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a772_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_8a772_row1_col1" class="data row1 col1" >perez</td>
#       <td id="T_8a772_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_8a772_row1_col3" class="data row1 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_8a772_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8a772_row

# %% [markdown]
# ## XGBRegressor

# %%
attributes = [
    "positionGrid",
    "driverRef",
    "weatherWet",
    "circuitType",
    "driverPodiums",
    "driverPos2",
    "driverPos3",
    "driverPos5",
    "driverPos6",
    "driverPos7",
    "driverPos8",
    "driverPos10",
    "driverPos12",
    "driverPos14",
    "driverPos15",
    "driverPos17",
    "driverPac",
    "driverOvr",
]
model = XGBRegressor(
    objective="reg:linear",
    learning_rate=0.18517350997324947,
    n_estimators=395,
    max_depth=16,
    min_child_weight=94,
    gamma=0.16242064862534417,
    subsample=0.6071469551618005,
    colsample_bytree=0.7848869553625191,
    reg_alpha=64,
    reg_lambda=100,
)
model_prediction(
    model,
    X_train[attributes],
    y_train - 1,
    X_test[attributes],
    y_test - 1,
    columns=columns,
    multiclass=True,
)
# Out:
# <div style='height: 550px'><style type="text/css">
# #T_ccf19_row0_col0, #T_ccf19_row0_col1, #T_ccf19_row0_col2, #T_ccf19_row0_col3, #T_ccf19_row1_col0, #T_ccf19_row1_col1, #T_ccf19_row1_col2, #T_ccf19_row1_col3, #T_ccf19_row2_col0, #T_ccf19_row2_col1, #T_ccf19_row2_col2, #T_ccf19_row2_col3, #T_ccf19_row3_col0, #T_ccf19_row3_col1, #T_ccf19_row3_col2, #T_ccf19_row3_col3, #T_ccf19_row5_col0, #T_ccf19_row5_col1, #T_ccf19_row5_col2, #T_ccf19_row5_col3, #T_ccf19_row8_col0, #T_ccf19_row8_col1, #T_ccf19_row8_col2, #T_ccf19_row8_col3, #T_ccf19_row10_col0, #T_ccf19_row10_col1, #T_ccf19_row10_col2, #T_ccf19_row10_col3, #T_ccf19_row11_col0, #T_ccf19_row11_col1, #T_ccf19_row11_col2, #T_ccf19_row11_col3, #T_ccf19_row13_col0, #T_ccf19_row13_col1, #T_ccf19_row13_col2, #T_ccf19_row13_col3, #T_ccf19_row14_col0, #T_ccf19_row14_col1, #T_ccf19_row14_col2, #T_ccf19_row14_col3, #T_ccf19_row15_col0, #T_ccf19_row15_col1, #T_ccf19_row15_col2, #T_ccf19_row15_col3, #T_ccf19_row17_col0, #T_ccf19_row17_col1, #T_ccf19_row17_col2, #T_ccf19_row17_col3, #T_ccf19_row18_col0, #T_ccf19_row18_col1, #T_ccf19_row18_col2, #T_ccf19_row18_col3, #T_ccf19_row19_col0, #T_ccf19_row19_col1, #T_ccf19_row19_col2, #T_ccf19_row19_col3, #T_ccf19_row20_col0, #T_ccf19_row20_col1, #T_ccf19_row20_col2, #T_ccf19_row20_col3, #T_ccf19_row21_col0, #T_ccf19_row21_col1, #T_ccf19_row21_col2, #T_ccf19_row21_col3, #T_ccf19_row22_col0, #T_ccf19_row22_col1, #T_ccf19_row22_col2, #T_ccf19_row22_col3, #T_ccf19_row23_col0, #T_ccf19_row23_col1, #T_ccf19_row23_col2, #T_ccf19_row23_col3, #T_ccf19_row25_col0, #T_ccf19_row25_col1, #T_ccf19_row25_col2, #T_ccf19_row25_col3, #T_ccf19_row26_col0, #T_ccf19_row26_col1, #T_ccf19_row26_col2, #T_ccf19_row26_col3, #T_ccf19_row28_col0, #T_ccf19_row28_col1, #T_ccf19_row28_col2, #T_ccf19_row28_col3, #T_ccf19_row29_col0, #T_ccf19_row29_col1, #T_ccf19_row29_col2, #T_ccf19_row29_col3, #T_ccf19_row31_col0, #T_ccf19_row31_col1, #T_ccf19_row31_col2, #T_ccf19_row31_col3, #T_ccf19_row32_col0, #T_ccf19_row32_col1, #T_ccf19_row32_col2, #T_ccf19_row32_col3, #T_ccf19_row33_col0, #T_ccf19_row33_col1, #T_ccf19_row33_col2, #T_ccf19_row33_col3, #T_ccf19_row35_col0, #T_ccf19_row35_col1, #T_ccf19_row35_col2, #T_ccf19_row35_col3, #T_ccf19_row36_col0, #T_ccf19_row36_col1, #T_ccf19_row36_col2, #T_ccf19_row36_col3, #T_ccf19_row37_col0, #T_ccf19_row37_col1, #T_ccf19_row37_col2, #T_ccf19_row37_col3, #T_ccf19_row38_col0, #T_ccf19_row38_col1, #T_ccf19_row38_col2, #T_ccf19_row38_col3, #T_ccf19_row39_col0, #T_ccf19_row39_col1, #T_ccf19_row39_col2, #T_ccf19_row39_col3, #T_ccf19_row40_col0, #T_ccf19_row40_col1, #T_ccf19_row40_col2, #T_ccf19_row40_col3, #T_ccf19_row41_col0, #T_ccf19_row41_col1, #T_ccf19_row41_col2, #T_ccf19_row41_col3, #T_ccf19_row42_col0, #T_ccf19_row42_col1, #T_ccf19_row42_col2, #T_ccf19_row42_col3, #T_ccf19_row43_col0, #T_ccf19_row43_col1, #T_ccf19_row43_col2, #T_ccf19_row43_col3, #T_ccf19_row45_col0, #T_ccf19_row45_col1, #T_ccf19_row45_col2, #T_ccf19_row45_col3, #T_ccf19_row46_col0, #T_ccf19_row46_col1, #T_ccf19_row46_col2, #T_ccf19_row46_col3, #T_ccf19_row48_col0, #T_ccf19_row48_col1, #T_ccf19_row48_col2, #T_ccf19_row48_col3, #T_ccf19_row49_col0, #T_ccf19_row49_col1, #T_ccf19_row49_col2, #T_ccf19_row49_col3, #T_ccf19_row51_col0, #T_ccf19_row51_col1, #T_ccf19_row51_col2, #T_ccf19_row51_col3, #T_ccf19_row56_col0, #T_ccf19_row56_col1, #T_ccf19_row56_col2, #T_ccf19_row56_col3, #T_ccf19_row57_col0, #T_ccf19_row57_col1, #T_ccf19_row57_col2, #T_ccf19_row57_col3, #T_ccf19_row58_col0, #T_ccf19_row58_col1, #T_ccf19_row58_col2, #T_ccf19_row58_col3, #T_ccf19_row62_col0, #T_ccf19_row62_col1, #T_ccf19_row62_col2, #T_ccf19_row62_col3, #T_ccf19_row65_col0, #T_ccf19_row65_col1, #T_ccf19_row65_col2, #T_ccf19_row65_col3, #T_ccf19_row67_col0, #T_ccf19_row67_col1, #T_ccf19_row67_col2, #T_ccf19_row67_col3, #T_ccf19_row71_col0, #T_ccf19_row71_col1, #T_ccf19_row71_col2, #T_ccf19_row71_col3, #T_ccf19_row74_col0, #T_ccf19_row74_col1, #T_ccf19_row74_col2, #T_ccf19_row74_col3, #T_ccf19_row75_col0, #T_ccf19_row75_col1, #T_ccf19_row75_col2, #T_ccf19_row7 ...
#   background-color: #800000;
# }
# #T_ccf19_row4_col0, #T_ccf19_row4_col1, #T_ccf19_row4_col2, #T_ccf19_row4_col3, #T_ccf19_row6_col0, #T_ccf19_row6_col1, #T_ccf19_row6_col2, #T_ccf19_row6_col3, #T_ccf19_row7_col0, #T_ccf19_row7_col1, #T_ccf19_row7_col2, #T_ccf19_row7_col3, #T_ccf19_row9_col0, #T_ccf19_row9_col1, #T_ccf19_row9_col2, #T_ccf19_row9_col3, #T_ccf19_row12_col0, #T_ccf19_row12_col1, #T_ccf19_row12_col2, #T_ccf19_row12_col3, #T_ccf19_row16_col0, #T_ccf19_row16_col1, #T_ccf19_row16_col2, #T_ccf19_row16_col3, #T_ccf19_row24_col0, #T_ccf19_row24_col1, #T_ccf19_row24_col2, #T_ccf19_row24_col3, #T_ccf19_row27_col0, #T_ccf19_row27_col1, #T_ccf19_row27_col2, #T_ccf19_row27_col3, #T_ccf19_row30_col0, #T_ccf19_row30_col1, #T_ccf19_row30_col2, #T_ccf19_row30_col3, #T_ccf19_row34_col0, #T_ccf19_row34_col1, #T_ccf19_row34_col2, #T_ccf19_row34_col3, #T_ccf19_row44_col0, #T_ccf19_row44_col1, #T_ccf19_row44_col2, #T_ccf19_row44_col3, #T_ccf19_row47_col0, #T_ccf19_row47_col1, #T_ccf19_row47_col2, #T_ccf19_row47_col3, #T_ccf19_row50_col0, #T_ccf19_row50_col1, #T_ccf19_row50_col2, #T_ccf19_row50_col3, #T_ccf19_row52_col0, #T_ccf19_row52_col1, #T_ccf19_row52_col2, #T_ccf19_row52_col3, #T_ccf19_row53_col0, #T_ccf19_row53_col1, #T_ccf19_row53_col2, #T_ccf19_row53_col3, #T_ccf19_row54_col0, #T_ccf19_row54_col1, #T_ccf19_row54_col2, #T_ccf19_row54_col3, #T_ccf19_row55_col0, #T_ccf19_row55_col1, #T_ccf19_row55_col2, #T_ccf19_row55_col3, #T_ccf19_row59_col0, #T_ccf19_row59_col1, #T_ccf19_row59_col2, #T_ccf19_row59_col3, #T_ccf19_row60_col0, #T_ccf19_row60_col1, #T_ccf19_row60_col2, #T_ccf19_row60_col3, #T_ccf19_row61_col0, #T_ccf19_row61_col1, #T_ccf19_row61_col2, #T_ccf19_row61_col3, #T_ccf19_row63_col0, #T_ccf19_row63_col1, #T_ccf19_row63_col2, #T_ccf19_row63_col3, #T_ccf19_row64_col0, #T_ccf19_row64_col1, #T_ccf19_row64_col2, #T_ccf19_row64_col3, #T_ccf19_row66_col0, #T_ccf19_row66_col1, #T_ccf19_row66_col2, #T_ccf19_row66_col3, #T_ccf19_row68_col0, #T_ccf19_row68_col1, #T_ccf19_row68_col2, #T_ccf19_row68_col3, #T_ccf19_row69_col0, #T_ccf19_row69_col1, #T_ccf19_row69_col2, #T_ccf19_row69_col3, #T_ccf19_row70_col0, #T_ccf19_row70_col1, #T_ccf19_row70_col2, #T_ccf19_row70_col3, #T_ccf19_row72_col0, #T_ccf19_row72_col1, #T_ccf19_row72_col2, #T_ccf19_row72_col3, #T_ccf19_row73_col0, #T_ccf19_row73_col1, #T_ccf19_row73_col2, #T_ccf19_row73_col3 {
#   background-color: #1c542d;
# }
# </style>
# <table id="T_ccf19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccf19_level0_col0" class="col_heading level0 col0" >raceRound</th>
#       <th id="T_ccf19_level0_col1" class="col_heading level0 col1" >driverRef</th>
#       <th id="T_ccf19_level0_col2" class="col_heading level0 col2" >positionFinal</th>
#       <th id="T_ccf19_level0_col3" class="col_heading level0 col3" >positionPred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccf19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ccf19_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ccf19_row0_col1" class="data row0 col1" >max_verstappen</td>
#       <td id="T_ccf19_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_ccf19_row0_col3" class="data row0 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ccf19_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ccf19_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_ccf19_row1_col1" class="data row1 col1" >perez</td>
#       <td id="T_ccf19_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_ccf19_row1_col3" class="data row1 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_ccf19_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ccf19_row

# %% [markdown]
# ## XGBRanker

# %%
races_per_year = np.cumsum(
    [0] + df_train.groupby("raceYear")["raceRound"].max().to_list()
)
set_id = lambda y, r: r + (races_per_year[y - 2019])

X_train["qid"] = df_train.apply(lambda x: set_id(x["raceYear"], x["raceRound"]), axis=1)
X_test["qid"] = df_test["raceRound"] + X_train["qid"].max()

attributes = [
    "carNumber",
    "positionGrid",
    "driverRef",
    "driverNumber",
    "driverNationality",
    "constructorNationality",
    "raceRound",
    "raceTime",
    "circuitAlt",
    "driverWins",
    "constructorWins",
    "q1",
    "q2",
    "weather",
    "weatherWarm",
    "weatherDry",
    "weatherWet",
    "weatherCloudy",
    "circuitType",
    "circuitLength",
    "circuitLaps",
    "circuitDist",
    "qMin",
    "qMax",
    "driverAgeStarted",
    "driverExpYear",
    "driverExpRace",
    "driverPodiums",
    "driverPos2",
    "driverPos3",
    "driverPos4",
    "driverPos5",
    "driverPos6",
    "driverPos7",
    "driverPos8",
    "driverPos9",
    "driverPos10",
    "driverPos11",
    "driverPos14",
    "driverPos16",
    "driverPos18",
    "driverExp",
    "driverAwa",
    "driverPac",
    "qid",
]
model = XGBRanker(
    objective="rank:pairwise",
    learning_rate=0.04189820511305815,
    n_estimators=192,
    max_depth=9,
    min_child_weight=54,
    gamma=0.8661594450075584,
    subsample=0.8739552860337986,
    colsample_bytree=0.7763941630015024,
    reg_alpha=7,
    reg_lambda=14,
)
model_prediction(
    model,
    X_train[attributes],
    y_train,
    X_test[attributes],
    y_test,
    columns=columns,
    rank=True,
    multiclass=True,
)
# Out:
# <div style='height: 550px'><style type="text/css">
# #T_68fc7_row0_col0, #T_68fc7_row0_col1, #T_68fc7_row0_col2, #T_68fc7_row0_col3, #T_68fc7_row1_col0, #T_68fc7_row1_col1, #T_68fc7_row1_col2, #T_68fc7_row1_col3, #T_68fc7_row3_col0, #T_68fc7_row3_col1, #T_68fc7_row3_col2, #T_68fc7_row3_col3, #T_68fc7_row5_col0, #T_68fc7_row5_col1, #T_68fc7_row5_col2, #T_68fc7_row5_col3, #T_68fc7_row6_col0, #T_68fc7_row6_col1, #T_68fc7_row6_col2, #T_68fc7_row6_col3, #T_68fc7_row7_col0, #T_68fc7_row7_col1, #T_68fc7_row7_col2, #T_68fc7_row7_col3, #T_68fc7_row9_col0, #T_68fc7_row9_col1, #T_68fc7_row9_col2, #T_68fc7_row9_col3, #T_68fc7_row17_col0, #T_68fc7_row17_col1, #T_68fc7_row17_col2, #T_68fc7_row17_col3, #T_68fc7_row19_col0, #T_68fc7_row19_col1, #T_68fc7_row19_col2, #T_68fc7_row19_col3, #T_68fc7_row20_col0, #T_68fc7_row20_col1, #T_68fc7_row20_col2, #T_68fc7_row20_col3, #T_68fc7_row21_col0, #T_68fc7_row21_col1, #T_68fc7_row21_col2, #T_68fc7_row21_col3, #T_68fc7_row22_col0, #T_68fc7_row22_col1, #T_68fc7_row22_col2, #T_68fc7_row22_col3, #T_68fc7_row23_col0, #T_68fc7_row23_col1, #T_68fc7_row23_col2, #T_68fc7_row23_col3, #T_68fc7_row24_col0, #T_68fc7_row24_col1, #T_68fc7_row24_col2, #T_68fc7_row24_col3, #T_68fc7_row25_col0, #T_68fc7_row25_col1, #T_68fc7_row25_col2, #T_68fc7_row25_col3, #T_68fc7_row28_col0, #T_68fc7_row28_col1, #T_68fc7_row28_col2, #T_68fc7_row28_col3, #T_68fc7_row30_col0, #T_68fc7_row30_col1, #T_68fc7_row30_col2, #T_68fc7_row30_col3, #T_68fc7_row32_col0, #T_68fc7_row32_col1, #T_68fc7_row32_col2, #T_68fc7_row32_col3, #T_68fc7_row35_col0, #T_68fc7_row35_col1, #T_68fc7_row35_col2, #T_68fc7_row35_col3, #T_68fc7_row37_col0, #T_68fc7_row37_col1, #T_68fc7_row37_col2, #T_68fc7_row37_col3, #T_68fc7_row40_col0, #T_68fc7_row40_col1, #T_68fc7_row40_col2, #T_68fc7_row40_col3, #T_68fc7_row41_col0, #T_68fc7_row41_col1, #T_68fc7_row41_col2, #T_68fc7_row41_col3, #T_68fc7_row44_col0, #T_68fc7_row44_col1, #T_68fc7_row44_col2, #T_68fc7_row44_col3, #T_68fc7_row50_col0, #T_68fc7_row50_col1, #T_68fc7_row50_col2, #T_68fc7_row50_col3, #T_68fc7_row53_col0, #T_68fc7_row53_col1, #T_68fc7_row53_col2, #T_68fc7_row53_col3, #T_68fc7_row59_col0, #T_68fc7_row59_col1, #T_68fc7_row59_col2, #T_68fc7_row59_col3, #T_68fc7_row60_col0, #T_68fc7_row60_col1, #T_68fc7_row60_col2, #T_68fc7_row60_col3, #T_68fc7_row61_col0, #T_68fc7_row61_col1, #T_68fc7_row61_col2, #T_68fc7_row61_col3, #T_68fc7_row63_col0, #T_68fc7_row63_col1, #T_68fc7_row63_col2, #T_68fc7_row63_col3, #T_68fc7_row64_col0, #T_68fc7_row64_col1, #T_68fc7_row64_col2, #T_68fc7_row64_col3, #T_68fc7_row66_col0, #T_68fc7_row66_col1, #T_68fc7_row66_col2, #T_68fc7_row66_col3, #T_68fc7_row67_col0, #T_68fc7_row67_col1, #T_68fc7_row67_col2, #T_68fc7_row67_col3, #T_68fc7_row68_col0, #T_68fc7_row68_col1, #T_68fc7_row68_col2, #T_68fc7_row68_col3, #T_68fc7_row70_col0, #T_68fc7_row70_col1, #T_68fc7_row70_col2, #T_68fc7_row70_col3, #T_68fc7_row72_col0, #T_68fc7_row72_col1, #T_68fc7_row72_col2, #T_68fc7_row72_col3, #T_68fc7_row73_col0, #T_68fc7_row73_col1, #T_68fc7_row73_col2, #T_68fc7_row73_col3, #T_68fc7_row74_col0, #T_68fc7_row74_col1, #T_68fc7_row74_col2, #T_68fc7_row74_col3, #T_68fc7_row76_col0, #T_68fc7_row76_col1, #T_68fc7_row76_col2, #T_68fc7_row76_col3 {
#   background-color: #1c542d;
# }
# #T_68fc7_row2_col0, #T_68fc7_row2_col1, #T_68fc7_row2_col2, #T_68fc7_row2_col3, #T_68fc7_row4_col0, #T_68fc7_row4_col1, #T_68fc7_row4_col2, #T_68fc7_row4_col3, #T_68fc7_row8_col0, #T_68fc7_row8_col1, #T_68fc7_row8_col2, #T_68fc7_row8_col3, #T_68fc7_row10_col0, #T_68fc7_row10_col1, #T_68fc7_row10_col2, #T_68fc7_row10_col3, #T_68fc7_row11_col0, #T_68fc7_row11_col1, #T_68fc7_row11_col2, #T_68fc7_row11_col3, #T_68fc7_row12_col0, #T_68fc7_row12_col1, #T_68fc7_row12_col2, #T_68fc7_row12_col3, #T_68fc7_row13_col0, #T_68fc7_row13_col1, #T_68fc7_row13_col2, #T_68fc7_row13_col3, #T_68fc7_row14_col0, #T_68fc7_row14_col1, #T_68fc7_row14_col2, #T_68fc7_row14_col3, #T_68fc7_row15_col0, #T_68fc7_row15_col1, #T_68fc7_row15_col2, #T_68fc7_row15_col3, #T_68fc7_row16_col0, #T_68fc7_row16_col1, #T_68fc7_row16_col2, #T_68fc7_row16_col3, #T_68fc7_row18_col0, #T_68fc7_row18_col1, #T_68fc7_row18_col2, #T_68fc7_row18_col3, #T_68fc7_row26_col0, #T_68fc7_row26_col1, #T_68fc7_row26_col2, #T_68fc7_row26_col3, #T_68fc7_row27_col0, #T_68fc7_row27_col1, #T_68fc7_row27_col2, #T_68fc7_row27_col3, #T_68fc7_row29_col0, #T_68fc7_row29_col1, #T_68fc7_row29_col2, #T_68fc7_row29_col3, #T_68fc7_row31_col0, #T_68fc7_row31_col1, #T_68fc7_row31_col2, #T_68fc7_row31_col3, #T_68fc7_row33_col0, #T_68fc7_row33_col1, #T_68fc7_row33_col2, #T_68fc7_row33_col3, #T_68fc7_row34_col0, #T_68fc7_row34_col1, #T_68fc7_row34_col2, #T_68fc7_row34_col3, #T_68fc7_row36_col0, #T_68fc7_row36_col1, #T_68fc7_row36_col2, #T_68fc7_row36_col3, #T_68fc7_row38_col0, #T_68fc7_row38_col1, #T_68fc7_row38_col2, #T_68fc7_row38_col3, #T_68fc7_row39_col0, #T_68fc7_row39_col1, #T_68fc7_row39_col2, #T_68fc7_row39_col3, #T_68fc7_row42_col0, #T_68fc7_row42_col1, #T_68fc7_row42_col2, #T_68fc7_row42_col3, #T_68fc7_row43_col0, #T_68fc7_row43_col1, #T_68fc7_row43_col2, #T_68fc7_row43_col3, #T_68fc7_row45_col0, #T_68fc7_row45_col1, #T_68fc7_row45_col2, #T_68fc7_row45_col3, #T_68fc7_row46_col0, #T_68fc7_row46_col1, #T_68fc7_row46_col2, #T_68fc7_row46_col3, #T_68fc7_row47_col0, #T_68fc7_row47_col1, #T_68fc7_row47_col2, #T_68fc7_row47_col3, #T_68fc7_row48_col0, #T_68fc7_row48_col1, #T_68fc7_row48_col2, #T_68fc7_row48_col3, #T_68fc7_row49_col0, #T_68fc7_row49_col1, #T_68fc7_row49_col2, #T_68fc7_row49_col3, #T_68fc7_row51_col0, #T_68fc7_row51_col1, #T_68fc7_row51_col2, #T_68fc7_row51_col3, #T_68fc7_row52_col0, #T_68fc7_row52_col1, #T_68fc7_row52_col2, #T_68fc7_row52_col3, #T_68fc7_row54_col0, #T_68fc7_row54_col1, #T_68fc7_row54_col2, #T_68fc7_row54_col3, #T_68fc7_row55_col0, #T_68fc7_row55_col1, #T_68fc7_row55_col2, #T_68fc7_row55_col3, #T_68fc7_row56_col0, #T_68fc7_row56_col1, #T_68fc7_row56_col2, #T_68fc7_row56_col3, #T_68fc7_row57_col0, #T_68fc7_row57_col1, #T_68fc7_row57_col2, #T_68fc7_row57_col3, #T_68fc7_row58_col0, #T_68fc7_row58_col1, #T_68fc7_row58_col2, #T_68fc7_row58_col3, #T_68fc7_row62_col0, #T_68fc7_row62_col1, #T_68fc7_row62_col2, #T_68fc7_row62_col3, #T_68fc7_row65_col0, #T_68fc7_row65_col1, #T_68fc7_row65_col2, #T_68fc7_row65_col3, #T_68fc7_row69_col0, #T_68fc7_row69_col1, #T_68fc7_row69_col2, #T_68fc7_row69_col3, #T_68fc7_row71_col0, #T_68fc7_row71_col1, #T_68fc7_row71_col2, #T_68fc7_row71_col3, #T_68fc7_row75_col0, #T_68fc7_row75_col1, #T_68fc7_row75_col2, #T_68fc7_row75_col3, #T_68fc7_row77_col0, #T_68fc7_row77_col1, #T_68fc7_row77_col2, #T_68fc7_row77_col3, #T_68fc7_row78_col0, #T_68fc7_row78_col1, #T_68fc7_row78_col2, #T_68fc7_row78_col3 {
#   background-color: #800000;
# }
# </style>
# <table id="T_68fc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68fc7_level0_col0" class="col_heading level0 col0" >raceRound</th>
#       <th id="T_68fc7_level0_col1" class="col_heading level0 col1" >driverRef</th>
#       <th id="T_68fc7_level0_col2" class="col_heading level0 col2" >positionFinal</th>
#       <th id="T_68fc7_level0_col3" class="col_heading level0 col3" >positionPred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68fc7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68fc7_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_68fc7_row0_col1" class="data row0 col1" >max_verstappen</td>
#       <td id="T_68fc7_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_68fc7_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_68fc7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68fc7_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_68fc7_row1_col1" class="data row1 col1" >perez</td>
#       <td id="T_68fc7_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_68fc7_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_68fc7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_68fc7_row

# %% [markdown]
# ## Results

# %% [markdown]
# We can also observe how, in general, the percentage is met. Also, as we advance in the careers, there is more consistency in the hits, which may be that there are several attributes that provide more information as the season progresses. Similarly, the first positions are also more consistent, probably because the drivers keep their positions with respect to the grid than the last ones.
